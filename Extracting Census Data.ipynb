# %% [markdown]
# ### Quality of Life Explorer

# %% [markdown]
# ##### Import Libraries
#
# - To run this script we need the libraries below
# - Pandas : For creating DataFrames
# - Numpy:  For computations
# - OS : For modifying working directories
# - censusdata: This is a library for accessing US Census Bureau, we use some of its function to preview variables *
# - Census: Main library for accessing the US Census Bureau API *
# - pd.set_option allows us to view our entire output instead of it being truncated in jupyter notebook
#
#
#
#  * You need to install these packages before you can use. Census = pip install census | censusdata = pip install CensusData

# %%
import pandas as pd
import numpy as np
import os
import censusdata as cs
from census import Census
pd.set_option('display.max_rows',None, 'display.max_columns',None,'display.max_colwidth', None)

# %% [markdown]
# ##### Set Directory
#
# - Jupyter notebooks have default directories
# - Use os.chdir to set your preferred directory

# %%
path = "C:\\Users\\padu\\Desktop\\UrbanInstitute\\CensusData"
os.chdir(path)

# %%
pwd
# Out:
# 'C:\\Users\\padu\\Downloads'

# %% [markdown]
# ##### Pass your API Key
#
# - Go to this [website](https://api.census.gov/data/key_signup.html 'sign up for your personal API key') and sign up your personal API key
#
# - Once you get your API key, call the Census function and pass your API key. Eg. Census("API Key")

# %%
c = Census("e0577a26a616f4dda60446eae987e3b6d0d944a3")

# %% [markdown]
# #### Preview ACS variable
# - Use the censustable function from censusdata library to preview the census variables
# - To preview specify the dataset type eg. ACS year 5 estimates (acs5), then the year of interest(2019), then the table number('B21001')
# - Use the printtable function to format the output nicely

# %%
cs.printtable(cs.censustable('acs5',2019,'B03002'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B03002_001E  | HISPANIC OR LATINO ORIGIN BY R | !! Estimate Total:                                       | int
# B03002_002E  | HISPANIC OR LATINO ORIGIN BY R | !! !! Estimate Total: Not Hispanic or Latino:            | int
# B03002_003E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: White a | int
# B03002_004E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Black o | int
# B03002_005E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: America | int
# B03002_006E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Asian a | int
# B03002_007E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Native  | int
# B03002_008E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Some ot | int
# B03002_009E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Two or  | int
# B03002_010E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Not Hispanic or Latino: Two  | int
# B03002_011E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Not Hispanic or Latino: Two  | int
# B03002_012E  | HISPANIC OR LATINO ORIGIN BY R | !! !! Estimate Total: Hispanic or Latino:                | int
# B03002_013E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: White alone | int
# B03002_014E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Black or Af | int
# B03002_015E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: American In | int
# B03002_016E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Asian alone | int
# B03002_017E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Native Hawa | int
# B03002_018E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Some other  | int
# B03002_019E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Two or more | int
# B03002_020E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Hispanic or Latino: Two or m | int
# B03002_021E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Hispanic or Latino: Two or m | int
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Downloading ACS data
# - We use the census library to download ACS variables for the census API.
# - We are able to access the census API because we passed our unique API key in the step above
# - To access the data with census library, we have to specify the dataset of interest(acs5) and call the 'get' function
# - The get function needs few key parameters including : NAME, ACS variable ID, geography of interest, and year of interest
#
#     - Name: The name parameter reports the census block name
#
#     - ACS Variable: The variable has to be specific, Estimates has E at the end, Margion of Error has M
#
#     - Geography: The geography uses a python dictionary.i.e key value pairs. we are interested in all blockgroup in Mecklenburg county. To get those we have to specify the geography using (for:name of geography and asteriks since we want all blockgroups), then for the county we have to specify the State ID (NC ID is 37) and the County ID (Meck County ID is 119), then the year (2019)
#
# - The output after running the get function is a dictionary, so we wrap it in pandas DataFrame for further analysis

# %%
Data = pd.DataFrame(c.acs5.get(('NAME',
                                ###
                                'B28011_004E', 'B28011_004M', 'B28011_001E','B28011_001M'
                                ######################### Median ##################################
                               ),{'for':'block group:*',
                                   'in':'state:37 county:119'}, year = 2020))
# Data

# %%
Data
# Out:
#                                                                       NAME  \
# 0     Block Group 2, Census Tract 1.01, Mecklenburg County, North Carolina
# 1     Block Group 1, Census Tract 1.03, Mecklenburg County, North Carolina
# 2        Block Group 1, Census Tract 8, Mecklenburg County, North Carolina
# 3        Block Group 2, Census Tract 9, Mecklenburg County, North Carolina
# 4       Block Group 1, Census Tract 11, Mecklenburg County, North Carolina
# 5       Block Group 1, Census Tract 12, Mecklenburg County, North Carolina
# 6       Block Group 1, Census Tract 13, Mecklenburg County, North Carolina
# 7       Block Group 1, Census Tract 14, Mecklenburg County, North Carolina
# 8    Block Group 2, Census Tract 15.04, Mecklenburg County, North Carolina
# 9    Block Group 2, Census Tract 15.05, Mecklenburg County, North Carolina
# 10   Block Group 3, Census Tract 15.07, Mecklenburg County, North Carolina
# 11   Block Group 3, Census Tract 15.08, Mecklenburg County, North Carolina
# 12   Block Group 1, Census Tract 15.10, Mecklenburg County, North Carolina
# 13   Block Group 2, Census Tract 16.03, Mecklenburg County, North Carolina
# 14   Block Group 2, Census Tract 16.06, Mecklenburg County, North Carolina
# 15   Block Group 2, Census Tract 18.02, Mecklenburg County, North Carolina
# 16   Block Group 3, Census Tract 19.10, Mecklenburg County, North Carolina
# 17   Block Group 3, Census Tract 19.11, Mecklenburg County, North Carolina
# 18   Block Group 1, Census Tract 19.16, Mecklenburg County, North Carolina
# 19   Block Group 2, Census Tract 19.17, Mecklenburg County, North Carolina
# 20   Block Group 3, Census Tract 19.18, Mecklenburg County, North Carolina
# 21   Block Group 1, Census Tract 19.20, Mecklenburg County, North Carolina
# 22   Block Group 1, Census Tract 19.21, Mecklenburg County, North Carolina
# 23   Block Group 1, Census Tract 19.23, Mecklenburg County, North Carolina
# 24   Block Group 1, Census Tract 19.25, Mecklenburg County, North Carolina
# 25   Block Group 1, Census Tract 19.26, Mecklenburg County, North Carolina
# 26   Block Group 2, Census Tract 19.27, Mecklenburg County, North Carolina
# 27   Block Group 3, Census Tract 20.04, Mecklenburg County, North Carolina
# 28   Block Group 1, Census Tract 20.06, Mecklenburg County, North Carolina
# 29      Block Group 2, Census Tract 24, Mecklenburg County, North Carolina
# 30      Block Group 2, Census Tract 25, Mecklenburg County, North Carolina
# 31   Block Group 2, Census Tract 27.01, Mecklenburg County, North Carolina
# 32   Block Group 2, Census Tract 27.02, Mecklenburg County, North Carolina
# 33      Block Group 2, Census Tract 28, Mecklenburg County, North Carolina
# 34   Block Group 2, Census Tract 29.03, Mecklenburg County, North Carolina
# 35   Block Group 2, Census Tract 29.05, Mecklenburg County, North Carolina
# 36   Block Group 1, Census Tract 29.08, Mecklenburg County, North Carolina
# 37   Block Group 1, Census Tract 29.09, Mecklenburg County, North Carolina
# 38   Block Group 3, Census Tract 29.10, Mecklenburg County, North Carolina
# 39   Block Group 2, Census Tract 30.08, Mecklenburg County, North Carolina
# 40   Block Group 2, Census Tract 30.12, Mecklenburg County, North Carolina
# 41   Block Group 1, Census Tract 30.15, Mecklenburg County, North Carolina
# 42   Block Group 2, Census Tract 30.22, Mecklenburg County, North Carolina
# 43   Block Group 2, Census Tract 31.02, Mecklenburg County, North Carolina
# 44   Block Group 2, Census Tract 31.05, Mecklenburg County, North Carolina
# 45   Block Group 2, Census Tract 31.08, Mecklenburg County, North Carolina
# 46   Block Group 1, Census Tract 31.10, Mecklenburg County, North Carolina
# 47   Block Group 3, Census Tract 31.11, Mecklenburg County, North Carolina
# 48   Block Group 1, Census Tract 32.03, Mecklenburg County, North Carolina
# 49   Block Group 2, Census Tract 32.04, Mecklenburg County, North Carolina
# 50   Block Group 2, Census Tract 33.01, Mecklenburg County, North Carolina
# 51   Block Group 1, Census Tract 34.01, Mecklenburg County, North Carolina
# 52   Block Group 2, Census Tract 34.02, Mecklenburg County, North Carolina
# 53      Block Group 1, Census Tract 36, Mecklenburg County, North Carolina
# 54      Block Group 4, Census Tract 36, Mecklenburg County, North Carolina
# 55   Block Group 2, Census Tract 38.10, Mecklenburg County, North Carolina
# 56   Block Group 2, Census Tract 39.02, Mecklenburg County, North Carolina
# 57   Block Group 1, Census Tract 39.03, Mecklenburg County, North Carolina
# 58      Block Group 2, Census Tract 40, Mecklenburg County, North Carolina
# 59   Block Group 1, Census Tract 41.01, Mecklenburg County, North Carolina
# 60   Block Group 2, Census Tract 41.02, Mecklenburg County, North Carolina
# 61      Block Group 4, Census Tract 42, Mecklenburg County, North Carolina
# 62   Block Group 3, Census Tract 43.02, Mecklenburg County, North Carolina
# 63   Block Group 2, Census Tract 43.04, Mecklenburg County, North Carolina
# 64   Block Group 1, Census Tract 43.07, Mecklenburg County, North Carolina
# 65      Block Group 3, Census Tract 44, Mecklenburg County, North Carolina
# 66      Block Group 3, Census Tract 45, Mecklenburg County, North Carolina
# 67      Block Group 1, Census Tract 47, Mecklenburg County, North Carolina
# 68   Block Group 1, Census Tract 53.06, Mecklenburg County, North Carolina
# 69   Block Group 2, Census Tract 53.07, Mecklenburg County, North Carolina
# 70   Block Group 2, Census Tract 54.03, Mecklenburg County, North Carolina
# 71   Block Group 1, Census Tract 54.05, Mecklenburg County, North Carolina
# 72   Block Group 2, Census Tract 54.06, Mecklenburg County, North Carolina
# 73   Block Group 1, Census Tract 55.10, Mecklenburg County, North Carolina
# 74   Block Group 1, Census Tract 55.11, Mecklenburg County, North Carolina
# 75   Block Group 1, Census Tract 55.12, Mecklenburg County, North Carolina
# 76   Block Group 1, Census Tract 55.13, Mecklenburg County, North Carolina
# 77   Block Group 1, Census Tract 55.15, Mecklenburg County, North Carolina
# 78   Block Group 3, Census Tract 55.17, Mecklenburg County, North Carolina
# 79   Block Group 3, Census Tract 55.19, Mecklenburg County, North Carolina
# 80   Block Group 3, Census Tract 55.20, Mecklenburg County, North Carolina
# 81   Block Group 2, Census Tract 55.32, Mecklenburg County, North Carolina
# 82   Block Group 2, Census Tract 55.34, Mecklenburg County, North Carolina
# 83   Block Group 2, Census Tract 55.35, Mecklenburg County, North Carolina
# 84   Block Group 3, Census Tract 55.36, Mecklenburg County, North Carolina
# 85   Block Group 2, Census Tract 56.04, Mecklenburg County, North Carolina
# 86   Block Group 2, Census Tract 56.09, Mecklenburg County, North Carolina
# 87   Block Group 2, Census Tract 56.11, Mecklenburg County, North Carolina
# 88   Block Group 1, Census Tract 56.13, Mecklenburg County, North Carolina
# 89   Block Group 1, Census Tract 56.17, Mecklenburg County, North Carolina
# 90   Block Group 2, Census Tract 56.18, Mecklenburg County, North Carolina
# 91   Block Group 1, Census Tract 56.21, Mecklenburg County, North Carolina
# 92   Block Group 1, Census Tract 56.22, Mecklenburg County, North Carolina
# 93   Block Group 2, Census Tract 56.23, Mecklenburg County, North Carolina
# 94   Block Group 2, Census Tract 56.25, Mecklenburg County, North Carolina
# 95   Block Group 3, Census Tract 57.14, Mecklenburg County, North Carolina
# 96   Block Group 2, Census Tract 57.16, Mecklenburg County, North Carolina
# 97   Block Group 1, Census Tract 57.19, Mecklenburg County, North Carolina
# 98   Block Group 1, Census Tract 57.21, Mecklenburg County, North Carolina
# 99   Block Group 1, Census Tract 57.23, Mecklenburg County, North Carolina
# 100  Block Group 2, Census Tract 58.11, Mecklenburg County, North Carolina
# 101  Block Group 1, Census Tract 58.16, Mecklenburg County, North Carolina
# 102  Block Group 2, Census Tract 58.17, Mecklenburg County, North Carolina
# 103  Block Group 1, Census Tract 58.26, Mecklenburg County, North Carolina
# 104  Block Group 1, Census Tract 58.28, Mecklenburg County, North Carolina
# 105  Block Group 1, Census Tract 58.29, Mecklenburg County, North Carolina
# 106  Block Group 2, Census Tract 58.30, Mecklenburg County, North Carolina
# 107  Block Group 2, Census Tract 58.33, Mecklenburg County, North Carolina
# 108  Block Group 2, Census Tract 58.34, Mecklenburg County, North Carolina
# 109  Block Group 2, Census Tract 58.47, Mecklenburg County, North Carolina
# 110  Block Group 2, Census Tract 58.48, Mecklenburg County, North Carolina
# 111  Block Group 2, Census Tract 58.49, Mecklenburg County, North Carolina
# 112  Block Group 2, Census Tract 58.51, Mecklenburg County, North Carolina
# 113  Block Group 2, Census Tract 58.53, Mecklenburg County, North Carolina
# 114  Block Group 2, Census Tract 58.55, Mecklenburg County, North Carolina
# 115  Block Group 1, Census Tract 58.58, Mecklenburg County, North Carolina
# 116  Block Group 1, Census Tract 58.60, Mecklenburg County, North Carolina
# 117  Block Group 2, Census Tract 58.61, Mecklenburg County, North Carolina
# 118  Block Group 2, Census Tract 58.63, Mecklenburg County, North Carolina
# 119  Block Group 1, Census Tract 58.65, Mecklenburg County, North Carolina
# 120  Block Group 1, Census Tract 58.68, Mecklenburg County, North Carolina
# 121  Block Group 2, Census Tract 59.10, Mecklenburg County, North Carolina
# 122  Block Group 2, Census Tract 59.20, Mecklenburg County, North Carolina
# 123  Block Group 2, Census Tract 59.22, Mecklenburg County, North Carolina
# 124  Block Group 1, Census Tract 59.24, Mecklenburg County, North Carolina
# 125  Block Group 1, Census Tract 59.26, Mecklenburg County, North Carolina
# 126  Block Group 2, Census Tract 59.27, Mecklenburg County, North Carolina
# 127  Block Group 2, Census Tract 59.29, Mecklenburg County, North Carolina
# 128  Block Group 1, Census Tract 59.32, Mecklenburg County, North Carolina
# 129  Block Group 1, Census Tract 60.08, Mecklenburg County, North Carolina
# 130  Block Group 2, Census Tract 60.09, Mecklenburg County, North Carolina
# 131  Block Group 2, Census Tract 60.12, Mecklenburg County, North Carolina
# 132  Block Group 1, Census Tract 60.14, Mecklenburg County, North Carolina
# 133  Block Group 2, Census Tract 60.15, Mecklenburg County, North Carolina
# 134  Block Group 1, Census Tract 61.03, Mecklenburg County, North Carolina
# 135  Block Group 1, Census Tract 61.08, Mecklenburg County, North Carolina
# 136  Block Group 2, Census Tract 61.15, Mecklenburg County, North Carolina
# 137  Block Group 1, Census Tract 62.09, Mecklenburg County, North Carolina
# 138  Block Group 1, Census Tract 62.10, Mecklenburg County, North Carolina
# 139  Block Group 2, Census Tract 62.11, Mecklenburg County, North Carolina
# 140  Block Group 1, Census Tract 62.14, Mecklenburg County, North Carolina
# 141  Block Group 2, Census Tract 62.17, Mecklenburg County, North Carolina
# 142  Block Group 1, Census Tract 62.20, Mecklenburg County, North Carolina
# 143  Block Group 1, Census Tract 62.22, Mecklenburg County, North Carolina
# 144  Block Group 1, Census Tract 62.24, Mecklenburg County, North Carolina
# 145  Block Group 1, Census Tract 63.07, Mecklenburg County, North Carolina
# 146  Block Group 1, Census Tract 63.09, Mecklenburg County, North Carolina
# 147  Block Group 2, Census Tract 63.11, Mecklenburg County, North Carolina
# 148  Block Group 3, Census Tract 64.03, Mecklenburg County, North Carolina
# 149  Block Group 3, Census Tract 64.04, Mecklenburg County, North Carolina
# 150  Block Group 3, Census Tract 58.66, Mecklenburg County, North Carolina
# 151  Block Group 2, Census Tract 15.09, Mecklenburg County, North Carolina
# 152     Block Group 3, Census Tract 28, Mecklenburg County, North Carolina
# 153  Block Group 1, Census Tract 31.05, Mecklenburg County, North Carolina
# 154     Block Group 3, Census Tract 42, Mecklenburg County, North Carolina
# 155  Block Group 1, Census Tract 54.06, Mecklenburg County, North Carolina
# 156     Block Group 3, Census Tract 52, Mecklenburg County, North Carolina
# 157  Block Group 1, Census Tract 53.01, Mecklenburg County, North Carolina
# 158  Block Group 2, Census Tract 53.01, Mecklenburg County, North Carolina
# 159  Block Group 1, Census Tract 53.05, Mecklenburg County, North Carolina
# 160  Block Group 2, Census Tract 53.05, Mecklenburg County, North Carolina
# 161  Block Group 3, Census Tract 53.05, Mecklenburg County, North Carolina
# 162  Block Group 2, Census Tract 53.06, Mecklenburg County, North Carolina
# 163  Block Group 1, Census Tract 53.07, Mecklenburg County, North Carolina
# 164  Block Group 1, Census Tract 53.08, Mecklenburg County, North Carolina
# 165  Block Group 2, Census Tract 53.08, Mecklenburg County, North Carolina
# 166  Block Group 1, Census Tract 54.03, Mecklenburg County, North Carolina
# 167  Block Group 1, Census Tract 54.04, Mecklenburg County, North Carolina
# 168  Block Group 2, Census Tract 54.04, Mecklenburg County, North Carolina
# 169  Block Group 2, Census Tract 54.05, Mecklenburg County, North Carolina
# 170  Block Group 1, Census Tract 55.08, Mecklenburg County, North Carolina
# 171  Block Group 2, Census Tract 55.08, Mecklenburg County, North Carolina
# 172  Block Group 2, Census Tract 55.10, Mecklenburg County, North Carolina
# 173  Block Group 3, Census Tract 55.10, Mecklenburg County, North Carolina
# 174  Block Group 2, Census Tract 55.11, Mecklenburg County, North Carolina
# 175  Block Group 3, Census Tract 55.11, Mecklenburg County, North Carolina
# 176  Block Group 2, Census Tract 55.12, Mecklenburg County, North Carolina
# 177  Block Group 3, Census Tract 55.12, Mecklenburg County, North Carolina
# 178  Block Group 2, Census Tract 55.13, Mecklenburg County, North Carolina
# 179  Block Group 3, Census Tract 55.13, Mecklenburg County, North Carolina
# 180  Block Group 1, Census Tract 55.16, Mecklenburg County, North Carolina
# 181  Block Group 1, Census Tract 55.17, Mecklenburg County, North Carolina
# 182  Block Group 2, Census Tract 55.17, Mecklenburg County, North Carolina
# 183  Block Group 1, Census Tract 55.19, Mecklenburg County, North Carolina
# 184  Block Group 2, Census Tract 55.19, Mecklenburg County, North Carolina
# 185  Block Group 1, Census Tract 55.20, Mecklenburg County, North Carolina
# 186  Block Group 2, Census Tract 55.20, Mecklenburg County, North Carolina
# 187  Block Group 1, Census Tract 55.22, Mecklenburg County, North Carolina
# 188  Block Group 2, Census Tract 55.22, Mecklenburg County, North Carolina
# 189  Block Group 3, Census Tract 55.22, Mecklenburg County, North Carolina
# 190  Block Group 1, Census Tract 55.25, Mecklenburg County, North Carolina
# 191  Block Group 2, Census Tract 55.25, Mecklenburg County, North Carolina
# 192  Block Group 1, Census Tract 55.26, Mecklenburg County, North Carolina
# 193  Block Group 2, Census Tract 55.26, Mecklenburg County, North Carolina
# 194  Block Group 1, Census Tract 55.27, Mecklenburg County, North Carolina
# 195  Block Group 1, Census Tract 55.28, Mecklenburg County, North Carolina
# 196  Block Group 2, Census Tract 55.28, Mecklenburg County, North Carolina
# 197  Block Group 1, Census Tract 55.29, Mecklenburg County, North Carolina
# 198  Block Group 1, Census Tract 55.30, Mecklenburg County, North Carolina
# 199  Block Group 2, Census Tract 55.30, Mecklenburg County, North Carolina
# 200  Block Group 1, Census Tract 55.31, Mecklenburg County, North Carolina
# 201  Block Group 2, Census Tract 55.31, Mecklenburg County, North Carolina
# 202  Block Group 1, Census Tract 55.32, Mecklenburg County, North Carolina
# 203  Block Group 1, Census Tract 55.33, Mecklenburg County, North Carolina
# 204  Block Group 1, Census Tract 55.34, Mecklenburg County, North Carolina
# 205  Block Group 3, Census Tract 55.34, Mecklenburg County, North Carolina
# 206  Block Group 1, Census Tract 55.35, Mecklenburg County, North Carolina
# 207  Block Group 1, Census Tract 55.36, Mecklenburg County, North Carolina
# 208  Block Group 2, Census Tract 55.36, Mecklenburg County, North Carolina
# 209  Block Group 4, Census Tract 55.36, Mecklenburg County, North Carolina
# 210  Block Group 1, Census Tract 56.04, Mecklenburg County, North Carolina
# 211  Block Group 3, Census Tract 56.04, Mecklenburg County, North Carolina
# 212  Block Group 1, Census Tract 56.09, Mecklenburg County, North Carolina
# 213  Block Group 1, Census Tract 56.10, Mecklenburg County, North Carolina
# 214  Block Group 2, Census Tract 56.10, Mecklenburg County, North Carolina
# 215  Block Group 1, Census Tract 56.11, Mecklenburg County, North Carolina
# 216  Block Group 1, Census Tract 56.12, Mecklenburg County, North Carolina
# 217  Block Group 2, Census Tract 56.12, Mecklenburg County, North Carolina
# 218  Block Group 1, Census Tract 56.15, Mecklenburg County, North Carolina
# 219  Block Group 1, Census Tract 56.16, Mecklenburg County, North Carolina
# 220  Block Group 2, Census Tract 56.17, Mecklenburg County, North Carolina
# 221  Block Group 1, Census Tract 56.18, Mecklenburg County, North Carolina
# 222  Block Group 1, Census Tract 56.19, Mecklenburg County, North Carolina
# 223  Block Group 2, Census Tract 56.19, Mecklenburg County, North Carolina
# 224  Block Group 2, Census Tract 56.21, Mecklenburg County, North Carolina
# 225  Block Group 3, Census Tract 56.21, Mecklenburg County, North Carolina
# 226  Block Group 2, Census Tract 56.22, Mecklenburg County, North Carolina
# 227  Block Group 1, Census Tract 56.23, Mecklenburg County, North Carolina
# 228  Block Group 1, Census Tract 56.24, Mecklenburg County, North Carolina
# 229  Block Group 1, Census Tract 56.25, Mecklenburg County, North Carolina
# 230  Block Group 1, Census Tract 56.26, Mecklenburg County, North Carolina
# 231  Block Group 1, Census Tract 56.27, Mecklenburg County, North Carolina
# 232  Block Group 2, Census Tract 56.27, Mecklenburg County, North Carolina
# 233  Block Group 3, Census Tract 56.27, Mecklenburg County, North Carolina
# 234  Block Group 1, Census Tract 57.09, Mecklenburg County, North Carolina
# 235  Block Group 2, Census Tract 57.09, Mecklenburg County, North Carolina
# 236  Block Group 1, Census Tract 57.10, Mecklenburg County, North Carolina
# 237  Block Group 2, Census Tract 57.10, Mecklenburg County, North Carolina
# 238  Block Group 1, Census Tract 57.12, Mecklenburg County, North Carolina
# 239  Block Group 2, Census Tract 57.12, Mecklenburg County, North Carolina
# 240  Block Group 1, Census Tract 57.13, Mecklenburg County, North Carolina
# 241  Block Group 2, Census Tract 57.13, Mecklenburg County, North Carolina
# 242  Block Group 1, Census Tract 57.14, Mecklenburg County, North Carolina
# 243  Block Group 2, Census Tract 57.14, Mecklenburg County, North Carolina
# 244  Block Group 1, Census Tract 57.15, Mecklenburg County, North Carolina
# 245  Block Group 1, Census Tract 57.16, Mecklenburg County, North Carolina
# 246  Block Group 1, Census Tract 57.18, Mecklenburg County, North Carolina
# 247  Block Group 2, Census Tract 57.18, Mecklenburg County, North Carolina
# 248  Block Group 2, Census Tract 57.19, Mecklenburg County, North Carolina
# 249  Block Group 1, Census Tract 57.20, Mecklenburg County, North Carolina
# 250  Block Group 2, Census Tract 57.21, Mecklenburg County, North Carolina
# 251  Block Group 1, Census Tract 57.22, Mecklenburg County, North Carolina
# 252  Block Group 2, Census Tract 57.23, Mecklenburg County, North Carolina
# 253  Block Group 1, Census Tract 58.11, Mecklenburg County, North Carolina
# 254  Block Group 3, Census Tract 58.11, Mecklenburg County, North Carolina
# 255  Block Group 1, Census Tract 58.15, Mecklenburg County, North Carolina
# 256  Block Group 2, Census Tract 58.15, Mecklenburg County, North Carolina
# 257  Block Group 2, Census Tract 58.16, Mecklenburg County, North Carolina
# 258  Block Group 1, Census Tract 58.17, Mecklenburg County, North Carolina
# 259  Block Group 1, Census Tract 58.24, Mecklenburg County, North Carolina
# 260  Block Group 2, Census Tract 58.24, Mecklenburg County, North Carolina
# 261  Block Group 2, Census Tract 58.26, Mecklenburg County, North Carolina
# 262  Block Group 1, Census Tract 58.27, Mecklenburg County, North Carolina
# 263  Block Group 2, Census Tract 58.28, Mecklenburg County, North Carolina
# 264  Block Group 3, Census Tract 58.28, Mecklenburg County, North Carolina
# 265  Block Group 2, Census Tract 58.29, Mecklenburg County, North Carolina
# 266  Block Group 1, Census Tract 58.30, Mecklenburg County, North Carolina
# 267  Block Group 1, Census Tract 58.32, Mecklenburg County, North Carolina
# 268  Block Group 1, Census Tract 58.33, Mecklenburg County, North Carolina
# 269  Block Group 3, Census Tract 58.33, Mecklenburg County, North Carolina
# 270  Block Group 1, Census Tract 58.34, Mecklenburg County, North Carolina
# 271  Block Group 1, Census Tract 58.35, Mecklenburg County, North Carolina
# 272  Block Group 1, Census Tract 58.36, Mecklenburg County, North Carolina
# 273  Block Group 2, Census Tract 58.36, Mecklenburg County, North Carolina
# 274  Block Group 1, Census Tract 58.39, Mecklenburg County, North Carolina
# 275  Block Group 2, Census Tract 58.39, Mecklenburg County, North Carolina
# 276  Block Group 1, Census Tract 58.40, Mecklenburg County, North Carolina
# 277  Block Group 1, Census Tract 58.43, Mecklenburg County, North Carolina
# 278  Block Group 2, Census Tract 58.43, Mecklenburg County, North Carolina
# 279  Block Group 1, Census Tract 58.45, Mecklenburg County, North Carolina
# 280  Block Group 2, Census Tract 58.45, Mecklenburg County, North Carolina
# 281  Block Group 3, Census Tract 58.45, Mecklenburg County, North Carolina
# 282  Block Group 1, Census Tract 58.46, Mecklenburg County, North Carolina
# 283  Block Group 2, Census Tract 58.46, Mecklenburg County, North Carolina
# 284  Block Group 1, Census Tract 58.47, Mecklenburg County, North Carolina
# 285  Block Group 3, Census Tract 58.47, Mecklenburg County, North Carolina
# 286  Block Group 1, Census Tract 58.48, Mecklenburg County, North Carolina
# 287  Block Group 3, Census Tract 58.48, Mecklenburg County, North Carolina
# 288  Block Group 1, Census Tract 58.49, Mecklenburg County, North Carolina
# 289  Block Group 1, Census Tract 58.50, Mecklenburg County, North Carolina
# 290  Block Group 1, Census Tract 58.51, Mecklenburg County, North Carolina
# 291  Block Group 1, Census Tract 58.52, Mecklenburg County, North Carolina
# 292  Block Group 1, Census Tract 58.53, Mecklenburg County, North Carolina
# 293  Block Group 1, Census Tract 58.54, Mecklenburg County, North Carolina
# 294  Block Group 1, Census Tract 58.55, Mecklenburg County, North Carolina
# 295  Block Group 3, Census Tract 58.55, Mecklenburg County, North Carolina
# 296  Block Group 1, Census Tract 58.56, Mecklenburg County, North Carolina
# 297  Block Group 1, Census Tract 58.57, Mecklenburg County, North Carolina
# 298  Block Group 2, Census Tract 58.58, Mecklenburg County, North Carolina
# 299  Block Group 1, Census Tract 58.59, Mecklenburg County, North Carolina
# 300  Block Group 2, Census Tract 58.60, Mecklenburg County, North Carolina
# 301  Block Group 1, Census Tract 58.61, Mecklenburg County, North Carolina
# 302  Block Group 1, Census Tract 58.62, Mecklenburg County, North Carolina
# 303  Block Group 1, Census Tract 58.63, Mecklenburg County, North Carolina
# 304  Block Group 1, Census Tract 58.64, Mecklenburg County, North Carolina
# 305  Block Group 2, Census Tract 58.64, Mecklenburg County, North Carolina
# 306  Block Group 1, Census Tract 58.66, Mecklenburg County, North Carolina
# 307  Block Group 2, Census Tract 58.66, Mecklenburg County, North Carolina
# 308  Block Group 1, Census Tract 58.67, Mecklenburg County, North Carolina
# 309  Block Group 2, Census Tract 58.67, Mecklenburg County, North Carolina
# 310  Block Group 1, Census Tract 59.08, Mecklenburg County, North Carolina
# 311  Block Group 1, Census Tract 59.10, Mecklenburg County, North Carolina
# 312  Block Group 1, Census Tract 59.13, Mecklenburg County, North Carolina
# 313  Block Group 2, Census Tract 59.13, Mecklenburg County, North Carolina
# 314  Block Group 3, Census Tract 59.13, Mecklenburg County, North Carolina
# 315  Block Group 4, Census Tract 59.13, Mecklenburg County, North Carolina
# 316  Block Group 1, Census Tract 59.15, Mecklenburg County, North Carolina
# 317  Block Group 2, Census Tract 59.15, Mecklenburg County, North Carolina
# 318  Block Group 1, Census Tract 59.16, Mecklenburg County, North Carolina
# 319  Block Group 2, Census Tract 59.16, Mecklenburg County, North Carolina
# 320  Block Group 1, Census Tract 59.18, Mecklenburg County, North Carolina
# 321  Block Group 2, Census Tract 59.18, Mecklenburg County, North Carolina
# 322  Block Group 3, Census Tract 59.18, Mecklenburg County, North Carolina
# 323  Block Group 1, Census Tract 59.19, Mecklenburg County, North Carolina
# 324  Block Group 2, Census Tract 59.19, Mecklenburg County, North Carolina
# 325  Block Group 1, Census Tract 59.20, Mecklenburg County, North Carolina
# 326  Block Group 1, Census Tract 59.21, Mecklenburg County, North Carolina
# 327  Block Group 1, Census Tract 59.22, Mecklenburg County, North Carolina
# 328  Block Group 1, Census Tract 59.23, Mecklenburg County, North Carolina
# 329  Block Group 2, Census Tract 59.23, Mecklenburg County, North Carolina
# 330  Block Group 2, Census Tract 59.24, Mecklenburg County, North Carolina
# 331  Block Group 1, Census Tract 59.25, Mecklenburg County, North Carolina
# 332  Block Group 2, Census Tract 59.26, Mecklenburg County, North Carolina
# 333  Block Group 1, Census Tract 59.27, Mecklenburg County, North Carolina
# 334  Block Group 1, Census Tract 59.28, Mecklenburg County, North Carolina
# 335  Block Group 1, Census Tract 59.29, Mecklenburg County, North Carolina
# 336  Block Group 1, Census Tract 59.30, Mecklenburg County, North Carolina
# 337  Block Group 1, Census Tract 59.31, Mecklenburg County, North Carolina
# 338  Block Group 2, Census Tract 59.31, Mecklenburg County, North Carolina
# 339  Block Group 1, Census Tract 60.05, Mecklenburg County, North Carolina
# 340  Block Group 2, Census Tract 60.05, Mecklenburg County, North Carolina
# 341  Block Group 2, Census Tract 60.08, Mecklenburg County, North Carolina
# 342  Block Group 1, Census Tract 60.09, Mecklenburg County, North Carolina
# 343  Block Group 1, Census Tract 60.11, Mecklenburg County, North Carolina
# 344  Block Group 1, Census Tract 60.12, Mecklenburg County, North Carolina
# 345  Block Group 1, Census Tract 60.13, Mecklenburg County, North Carolina
# 346  Block Group 2, Census Tract 60.13, Mecklenburg County, North Carolina
# 347  Block Group 2, Census Tract 60.14, Mecklenburg County, North Carolina
# 348  Block Group 1, Census Tract 60.15, Mecklenburg County, North Carolina
# 349  Block Group 1, Census Tract 60.16, Mecklenburg County, North Carolina
# 350  Block Group 2, Census Tract 60.16, Mecklenburg County, North Carolina
# 351  Block Group 2, Census Tract 61.03, Mecklenburg County, North Carolina
# 352  Block Group 1, Census Tract 61.05, Mecklenburg County, North Carolina
# 353  Block Group 2, Census Tract 61.08, Mecklenburg County, North Carolina
# 354  Block Group 1, Census Tract 61.09, Mecklenburg County, North Carolina
# 355  Block Group 1, Census Tract 61.10, Mecklenburg County, North Carolina
# 356  Block Group 2, Census Tract 61.10, Mecklenburg County, North Carolina
# 357  Block Group 3, Census Tract 61.10, Mecklenburg County, North Carolina
# 358  Block Group 1, Census Tract 61.11, Mecklenburg County, North Carolina
# 359  Block Group 2, Census Tract 61.11, Mecklenburg County, North Carolina
# 360  Block Group 1, Census Tract 61.12, Mecklenburg County, North Carolina
# 361  Block Group 2, Census Tract 61.12, Mecklenburg County, North Carolina
# 362  Block Group 1, Census Tract 61.13, Mecklenburg County, North Carolina
# 363  Block Group 2, Census Tract 61.13, Mecklenburg County, North Carolina
# 364  Block Group 1, Census Tract 61.14, Mecklenburg County, North Carolina
# 365  Block Group 2, Census Tract 61.14, Mecklenburg County, North Carolina
# 366  Block Group 1, Census Tract 61.15, Mecklenburg County, North Carolina
# 367  Block Group 1, Census Tract 62.08, Mecklenburg County, North Carolina
# 368  Block Group 2, Census Tract 62.08, Mecklenburg County, North Carolina
# 369  Block Group 2, Census Tract 62.09, Mecklenburg County, North Carolina
# 370  Block Group 3, Census Tract 62.09, Mecklenburg County, North Carolina
# 371  Block Group 2, Census Tract 62.10, Mecklenburg County, North Carolina
# 372  Block Group 1, Census Tract 62.11, Mecklenburg County, North Carolina
# 373  Block Group 1, Census Tract 62.12, Mecklenburg County, North Carolina
# 374  Block Group 2, Census Tract 62.12, Mecklenburg County, North Carolina
# 375  Block Group 2, Census Tract 62.14, Mecklenburg County, North Carolina
# 376  Block Group 1, Census Tract 62.16, Mecklenburg County, North Carolina
# 377  Block Group 1, Census Tract 62.17, Mecklenburg County, North Carolina
# 378  Block Group 1, Census Tract 62.18, Mecklenburg County, North Carolina
# 379  Block Group 1, Census Tract 62.19, Mecklenburg County, North Carolina
# 380  Block Group 2, Census Tract 62.20, Mecklenburg County, North Carolina
# 381  Block Group 1, Census Tract 62.21, Mecklenburg County, North Carolina
# 382  Block Group 2, Census Tract 62.22, Mecklenburg County, North Carolina
# 383  Block Group 1, Census Tract 62.23, Mecklenburg County, North Carolina
# 384  Block Group 1, Census Tract 63.05, Mecklenburg County, North Carolina
# 385  Block Group 1, Census Tract 63.06, Mecklenburg County, North Carolina
# 386  Block Group 2, Census Tract 63.07, Mecklenburg County, North Carolina
# 387  Block Group 1, Census Tract 63.08, Mecklenburg County, North Carolina
# 388  Block Group 1, Census Tract 63.10, Mecklenburg County, North Carolina
# 389  Block Group 1, Census Tract 63.11, Mecklenburg County, North Carolina
# 390  Block Group 1, Census Tract 64.03, Mecklenburg County, North Carolina
# 391  Block Group 2, Census Tract 64.03, Mecklenburg County, North Carolina
# 392  Block Group 1, Census Tract 64.04, Mecklenburg County, North Carolina
# 393  Block Group 2, Census Tract 64.04, Mecklenburg County, North Carolina
# 394  Block Group 1, Census Tract 64.07, Mecklenburg County, North Carolina
# 395  Block Group 2, Census Tract 64.07, Mecklenburg County, North Carolina
# 396  Block Group 1, Census Tract 64.08, Mecklenburg County, North Carolina
# 397  Block Group 2, Census Tract 64.08, Mecklenburg County, North Carolina
# 398  Block Group 1, Census Tract 64.09, Mecklenburg County, North Carolina
# 399  Block Group 1, Census Tract 64.10, Mecklenburg County, North Carolina
# 400  Block Group 2, Census Tract 64.10, Mecklenburg County, North Carolina
# 401  Block Group 1, Census Tract 64.11, Mecklenburg County, North Carolina
# 402  Block Group 2, Census Tract 64.11, Mecklenburg County, North Carolina
# 403   Block Group 1, Census Tract 9801, Mecklenburg County, North Carolina
# 404   Block Group 1, Census Tract 9802, Mecklenburg County, North Carolina
# 405   Block Group 1, Census Tract 9803, Mecklenburg County, North Carolina
# 406   Block Group 1, Census Tract 1.01, Mecklenburg County, North Carolina
# 407   Block Group 1, Census Tract 1.02, Mecklenburg County, North Carolina
# 408   Block Group 2, Census Tract 1.02, Mecklenburg County, North Carolina
# 409   Block Group 1, Census Tract 1.04, Mecklenburg County, North Carolina
# 410   Block Group 1, Census Tract 3.01, Mecklenburg County, North Carolina
# 411   Block Group 1, Census Tract 3.02, Mecklenburg County, North Carolina
# 412   Block Group 2, Census Tract 3.02, Mecklenburg County, North Carolina
# 413   Block Group 1, Census Tract 4.01, Mecklenburg County, North Carolina
# 414   Block Group 1, Census Tract 4.02, Mecklenburg County, North Carolina
# 415   Block Group 2, Census Tract 4.02, Mecklenburg County, North Carolina
# 416   Block Group 1, Census Tract 5.01, Mecklenburg County, North Carolina
# 417   Block Group 2, Census Tract 5.01, Mecklenburg County, North Carolina
# 418   Block Group 1, Census Tract 5.02, Mecklenburg County, North Carolina
# 419   Block Group 1, Census Tract 5.03, Mecklenburg County, North Carolina
# 420   Block Group 2, Census Tract 5.03, Mecklenburg County, North Carolina
# 421      Block Group 1, Census Tract 6, Mecklenburg County, North Carolina
# 422      Block Group 2, Census Tract 6, Mecklenburg County, North Carolina
# 423      Block Group 3, Census Tract 6, Mecklenburg County, North Carolina
# 424      Block Group 1, Census Tract 7, Mecklenburg County, North Carolina
# 425      Block Group 2, Census Tract 7, Mecklenburg County, North Carolina
# 426      Block Group 2, Census Tract 8, Mecklenburg County, North Carolina
# 427      Block Group 1, Census Tract 9, Mecklenburg County, North Carolina
# 428     Block Group 1, Census Tract 10, Mecklenburg County, North Carolina
# 429     Block Group 2, Census Tract 10, Mecklenburg County, North Carolina
# 430     Block Group 3, Census Tract 10, Mecklenburg County, North Carolina
# 431     Block Group 2, Census Tract 11, Mecklenburg County, North Carolina
# 432     Block Group 3, Census Tract 11, Mecklenburg County, North Carolina
# 433     Block Group 2, Census Tract 12, Mecklenburg County, North Carolina
# 434     Block Group 3, Census Tract 12, Mecklenburg County, North Carolina
# 435     Block Group 2, Census Tract 13, Mecklenburg County, North Carolina
# 436     Block Group 3, Census Tract 13, Mecklenburg County, North Carolina
# 437     Block Group 2, Census Tract 14, Mecklenburg County, North Carolina
# 438  Block Group 1, Census Tract 15.04, Mecklenburg County, North Carolina
# 439  Block Group 3, Census Tract 15.04, Mecklenburg County, North Carolina
# 440  Block Group 1, Census Tract 15.05, Mecklenburg County, North Carolina
# 441  Block Group 1, Census Tract 15.07, Mecklenburg County, North Carolina
# 442  Block Group 2, Census Tract 15.07, Mecklenburg County, North Carolina
# 443  Block Group 1, Census Tract 15.08, Mecklenburg County, North Carolina
# 444  Block Group 2, Census Tract 15.08, Mecklenburg County, North Carolina
# 445  Block Group 1, Census Tract 15.09, Mecklenburg County, North Carolina
# 446  Block Group 2, Census Tract 15.10, Mecklenburg County, North Carolina
# 447  Block Group 1, Census Tract 16.03, Mecklenburg County, North Carolina
# 448  Block Group 3, Census Tract 16.03, Mecklenburg County, North Carolina
# 449  Block Group 1, Census Tract 16.05, Mecklenburg County, North Carolina
# 450  Block Group 1, Census Tract 16.06, Mecklenburg County, North Carolina
# 451  Block Group 1, Census Tract 16.07, Mecklenburg County, North Carolina
# 452  Block Group 1, Census Tract 16.08, Mecklenburg County, North Carolina
# 453  Block Group 2, Census Tract 16.08, Mecklenburg County, North Carolina
# 454  Block Group 1, Census Tract 16.09, Mecklenburg County, North Carolina
# 455  Block Group 2, Census Tract 16.09, Mecklenburg County, North Carolina
# 456  Block Group 1, Census Tract 17.01, Mecklenburg County, North Carolina
# 457  Block Group 2, Census Tract 17.01, Mecklenburg County, North Carolina
# 458  Block Group 1, Census Tract 17.02, Mecklenburg County, North Carolina
# 459  Block Group 2, Census Tract 17.02, Mecklenburg County, North Carolina
# 460  Block Group 3, Census Tract 17.02, Mecklenburg County, North Carolina
# 461  Block Group 4, Census Tract 17.02, Mecklenburg County, North Carolina
# 462  Block Group 1, Census Tract 18.01, Mecklenburg County, North Carolina
# 463  Block Group 2, Census Tract 18.01, Mecklenburg County, North Carolina
# 464  Block Group 3, Census Tract 18.01, Mecklenburg County, North Carolina
# 465  Block Group 1, Census Tract 18.02, Mecklenburg County, North Carolina
# 466  Block Group 1, Census Tract 19.10, Mecklenburg County, North Carolina
# 467  Block Group 2, Census Tract 19.10, Mecklenburg County, North Carolina
# 468  Block Group 1, Census Tract 19.11, Mecklenburg County, North Carolina
# 469  Block Group 2, Census Tract 19.11, Mecklenburg County, North Carolina
# 470  Block Group 1, Census Tract 19.14, Mecklenburg County, North Carolina
# 471  Block Group 2, Census Tract 19.14, Mecklenburg County, North Carolina
# 472  Block Group 2, Census Tract 19.16, Mecklenburg County, North Carolina
# 473  Block Group 1, Census Tract 19.17, Mecklenburg County, North Carolina
# 474  Block Group 1, Census Tract 19.18, Mecklenburg County, North Carolina
# 475  Block Group 2, Census Tract 19.18, Mecklenburg County, North Carolina
# 476  Block Group 1, Census Tract 19.19, Mecklenburg County, North Carolina
# 477  Block Group 2, Census Tract 19.19, Mecklenburg County, North Carolina
# 478  Block Group 3, Census Tract 19.19, Mecklenburg County, North Carolina
# 479  Block Group 2, Census Tract 19.20, Mecklenburg County, North Carolina
# 480  Block Group 3, Census Tract 19.20, Mecklenburg County, North Carolina
# 481  Block Group 1, Census Tract 19.22, Mecklenburg County, North Carolina
# 482  Block Group 2, Census Tract 19.22, Mecklenburg County, North Carolina
# 483  Block Group 2, Census Tract 19.23, Mecklenburg County, North Carolina
# 484  Block Group 1, Census Tract 19.24, Mecklenburg County, North Carolina
# 485  Block Group 2, Census Tract 19.25, Mecklenburg County, North Carolina
# 486  Block Group 3, Census Tract 19.25, Mecklenburg County, North Carolina
# 487  Block Group 2, Census Tract 19.26, Mecklenburg County, North Carolina
# 488  Block Group 1, Census Tract 19.27, Mecklenburg County, North Carolina
# 489  Block Group 1, Census Tract 20.04, Mecklenburg County, North Carolina
# 490  Block Group 2, Census Tract 20.04, Mecklenburg County, North Carolina
# 491  Block Group 1, Census Tract 20.05, Mecklenburg County, North Carolina
# 492  Block Group 2, Census Tract 20.05, Mecklenburg County, North Carolina
# 493  Block Group 2, Census Tract 20.06, Mecklenburg County, North Carolina
# 494  Block Group 1, Census Tract 20.07, Mecklenburg County, North Carolina
# 495  Block Group 2, Census Tract 20.07, Mecklenburg County, North Carolina
# 496  Block Group 1, Census Tract 20.08, Mecklenburg County, North Carolina
# 497  Block Group 2, Census Tract 20.08, Mecklenburg County, North Carolina
# 498  Block Group 3, Census Tract 20.08, Mecklenburg County, North Carolina
# 499     Block Group 1, Census Tract 21, Mecklenburg County, North Carolina
# 500     Block Group 2, Census Tract 21, Mecklenburg County, North Carolina
# 501  Block Group 1, Census Tract 22.01, Mecklenburg County, North Carolina
# 502  Block Group 2, Census Tract 22.01, Mecklenburg County, North Carolina
# 503  Block Group 1, Census Tract 22.02, Mecklenburg County, North Carolina
# 504  Block Group 2, Census Tract 22.02, Mecklenburg County, North Carolina
# 505     Block Group 1, Census Tract 23, Mecklenburg County, North Carolina
# 506     Block Group 2, Census Tract 23, Mecklenburg County, North Carolina
# 507     Block Group 1, Census Tract 24, Mecklenburg County, North Carolina
# 508     Block Group 3, Census Tract 24, Mecklenburg County, North Carolina
# 509     Block Group 1, Census Tract 25, Mecklenburg County, North Carolina
# 510     Block Group 1, Census Tract 26, Mecklenburg County, North Carolina
# 511  Block Group 1, Census Tract 27.01, Mecklenburg County, North Carolina
# 512  Block Group 3, Census Tract 27.01, Mecklenburg County, North Carolina
# 513  Block Group 1, Census Tract 27.02, Mecklenburg County, North Carolina
# 514  Block Group 3, Census Tract 27.02, Mecklenburg County, North Carolina
# 515     Block Group 1, Census Tract 28, Mecklenburg County, North Carolina
# 516  Block Group 1, Census Tract 29.03, Mecklenburg County, North Carolina
# 517  Block Group 3, Census Tract 29.03, Mecklenburg County, North Carolina
# 518  Block Group 1, Census Tract 29.05, Mecklenburg County, North Carolina
# 519  Block Group 1, Census Tract 29.07, Mecklenburg County, North Carolina
# 520  Block Group 2, Census Tract 29.07, Mecklenburg County, North Carolina
# 521  Block Group 2, Census Tract 29.08, Mecklenburg County, North Carolina
# 522  Block Group 3, Census Tract 29.08, Mecklenburg County, North Carolina
# 523  Block Group 1, Census Tract 29.10, Mecklenburg County, North Carolina
# 524  Block Group 2, Census Tract 29.10, Mecklenburg County, North Carolina
# 525  Block Group 1, Census Tract 30.06, Mecklenburg County, North Carolina
# 526  Block Group 2, Census Tract 30.06, Mecklenburg County, North Carolina
# 527  Block Group 1, Census Tract 30.08, Mecklenburg County, North Carolina
# 528  Block Group 3, Census Tract 30.08, Mecklenburg County, North Carolina
# 529  Block Group 1, Census Tract 30.12, Mecklenburg County, North Carolina
# 530  Block Group 1, Census Tract 30.13, Mecklenburg County, North Carolina
# 531  Block Group 2, Census Tract 30.13, Mecklenburg County, North Carolina
# 532  Block Group 2, Census Tract 30.15, Mecklenburg County, North Carolina
# 533  Block Group 3, Census Tract 30.15, Mecklenburg County, North Carolina
# 534  Block Group 1, Census Tract 30.16, Mecklenburg County, North Carolina
# 535  Block Group 2, Census Tract 30.16, Mecklenburg County, North Carolina
# 536  Block Group 3, Census Tract 30.16, Mecklenburg County, North Carolina
# 537  Block Group 1, Census Tract 30.17, Mecklenburg County, North Carolina
# 538  Block Group 2, Census Tract 30.17, Mecklenburg County, North Carolina
# 539  Block Group 1, Census Tract 30.18, Mecklenburg County, North Carolina
# 540  Block Group 1, Census Tract 30.19, Mecklenburg County, North Carolina
# 541  Block Group 2, Census Tract 30.19, Mecklenburg County, North Carolina
# 542  Block Group 1, Census Tract 30.20, Mecklenburg County, North Carolina
# 543  Block Group 2, Census Tract 30.20, Mecklenburg County, North Carolina
# 544  Block Group 3, Census Tract 30.20, Mecklenburg County, North Carolina
# 545  Block Group 1, Census Tract 30.21, Mecklenburg County, North Carolina
# 546  Block Group 2, Census Tract 30.21, Mecklenburg County, North Carolina
# 547  Block Group 1, Census Tract 30.22, Mecklenburg County, North Carolina
# 548  Block Group 3, Census Tract 30.22, Mecklenburg County, North Carolina
# 549  Block Group 1, Census Tract 31.02, Mecklenburg County, North Carolina
# 550  Block Group 3, Census Tract 31.02, Mecklenburg County, North Carolina
# 551  Block Group 1, Census Tract 31.06, Mecklenburg County, North Carolina
# 552  Block Group 2, Census Tract 31.06, Mecklenburg County, North Carolina
# 553  Block Group 1, Census Tract 31.08, Mecklenburg County, North Carolina
# 554  Block Group 1, Census Tract 31.09, Mecklenburg County, North Carolina
# 555  Block Group 2, Census Tract 31.09, Mecklenburg County, North Carolina
# 556  Block Group 1, Census Tract 31.11, Mecklenburg County, North Carolina
# 557  Block Group 2, Census Tract 31.11, Mecklenburg County, North Carolina
# 558  Block Group 1, Census Tract 32.01, Mecklenburg County, North Carolina
# 559  Block Group 2, Census Tract 32.01, Mecklenburg County, North Carolina
# 560  Block Group 2, Census Tract 32.03, Mecklenburg County, North Carolina
# 561  Block Group 1, Census Tract 32.04, Mecklenburg County, North Carolina
# 562  Block Group 3, Census Tract 32.04, Mecklenburg County, North Carolina
# 563  Block Group 1, Census Tract 33.01, Mecklenburg County, North Carolina
# 564  Block Group 1, Census Tract 33.02, Mecklenburg County, North Carolina
# 565  Block Group 2, Census Tract 33.02, Mecklenburg County, North Carolina
# 566  Block Group 2, Census Tract 34.01, Mecklenburg County, North Carolina
# 567  Block Group 1, Census Tract 34.02, Mecklenburg County, North Carolina
# 568  Block Group 3, Census Tract 34.02, Mecklenburg County, North Carolina
# 569     Block Group 1, Census Tract 35, Mecklenburg County, North Carolina
# 570     Block Group 2, Census Tract 35, Mecklenburg County, North Carolina
# 571     Block Group 2, Census Tract 36, Mecklenburg County, North Carolina
# 572     Block Group 3, Census Tract 36, Mecklenburg County, North Carolina
# 573  Block Group 1, Census Tract 37.01, Mecklenburg County, North Carolina
# 574  Block Group 2, Census Tract 37.01, Mecklenburg County, North Carolina
# 575  Block Group 1, Census Tract 37.02, Mecklenburg County, North Carolina
# 576  Block Group 2, Census Tract 37.02, Mecklenburg County, North Carolina
# 577  Block Group 1, Census Tract 38.02, Mecklenburg County, North Carolina
# 578  Block Group 2, Census Tract 38.02, Mecklenburg County, North Carolina
# 579  Block Group 3, Census Tract 38.02, Mecklenburg County, North Carolina
# 580  Block Group 1, Census Tract 38.05, Mecklenburg County, North Carolina
# 581  Block Group 2, Census Tract 38.05, Mecklenburg County, North Carolina
# 582  Block Group 1, Census Tract 38.07, Mecklenburg County, North Carolina
# 583  Block Group 2, Census Tract 38.07, Mecklenburg County, North Carolina
# 584  Block Group 1, Census Tract 38.08, Mecklenburg County, North Carolina
# 585  Block Group 2, Census Tract 38.08, Mecklenburg County, North Carolina
# 586  Block Group 3, Census Tract 38.08, Mecklenburg County, North Carolina
# 587  Block Group 1, Census Tract 38.09, Mecklenburg County, North Carolina
# 588  Block Group 2, Census Tract 38.09, Mecklenburg County, North Carolina
# 589  Block Group 1, Census Tract 38.10, Mecklenburg County, North Carolina
# 590  Block Group 1, Census Tract 38.11, Mecklenburg County, North Carolina
# 591  Block Group 1, Census Tract 39.02, Mecklenburg County, North Carolina
# 592  Block Group 3, Census Tract 39.02, Mecklenburg County, North Carolina
# 593  Block Group 4, Census Tract 39.02, Mecklenburg County, North Carolina
# 594  Block Group 2, Census Tract 39.03, Mecklenburg County, North Carolina
# 595     Block Group 1, Census Tract 40, Mecklenburg County, North Carolina
# 596     Block Group 3, Census Tract 40, Mecklenburg County, North Carolina
# 597     Block Group 4, Census Tract 40, Mecklenburg County, North Carolina
# 598  Block Group 2, Census Tract 41.01, Mecklenburg County, North Carolina
# 599  Block Group 1, Census Tract 41.02, Mecklenburg County, North Carolina
# 600     Block Group 1, Census Tract 42, Mecklenburg County, North Carolina
# 601     Block Group 2, Census Tract 42, Mecklenburg County, North Carolina
# 602  Block Group 1, Census Tract 43.02, Mecklenburg County, North Carolina
# 603  Block Group 2, Census Tract 43.02, Mecklenburg County, North Carolina
# 604  Block Group 1, Census Tract 43.03, Mecklenburg County, North Carolina
# 605  Block Group 1, Census Tract 43.04, Mecklenburg County, North Carolina
# 606  Block Group 1, Census Tract 43.06, Mecklenburg County, North Carolina
# 607  Block Group 2, Census Tract 43.06, Mecklenburg County, North Carolina
# 608     Block Group 1, Census Tract 44, Mecklenburg County, North Carolina
# 609     Block Group 2, Census Tract 44, Mecklenburg County, North Carolina
# 610     Block Group 1, Census Tract 45, Mecklenburg County, North Carolina
# 611     Block Group 2, Census Tract 45, Mecklenburg County, North Carolina
# 612     Block Group 1, Census Tract 46, Mecklenburg County, North Carolina
# 613     Block Group 2, Census Tract 46, Mecklenburg County, North Carolina
# ...
# 565        333.0         72.0        443.0         83.0    37    119  003302
# 566        500.0        169.0        537.0        163.0    37    119  003401
# 567        595.0        111.0        630.0        116.0    37    119  003402
# 568        640.0        124.0        655.0        124.0    37    119  003402
# 569        908.0        332.0        991.0        335.0    37    119  003500
# 570        561.0        143.0        591.0        143.0    37    119  003500
# 571        476.0        105.0        579.0        113.0    37    119  003600
# 572        160.0         87.0        430.0        164.0    37    119  003600
# 573        858.0        263.0        904.0        260.0    37    119  003701
# 574         16.0         22.0        225.0         63.0    37    119  003701
# 575        559.0        213.0        621.0        212.0    37    119  003702
# 576        213.0         82.0        446.0        143.0    37    119  003702
# 577        203.0         79.0        360.0         89.0    37    119  003802
# 578        371.0        152.0        846.0        141.0    37    119  003802
# 579         18.0         19.0         34.0         27.0    37    119  003802
# 580        433.0        217.0        460.0        215.0    37    119  003805
# 581       1064.0        333.0       1383.0        387.0    37    119  003805
# 582        285.0        102.0        487.0        112.0    37    119  003807
# 583        661.0        176.0       1047.0        188.0    37    119  003807
# 584        108.0         67.0        608.0        123.0    37    119  003808
# 585        131.0         88.0        214.0         93.0    37    119  003808
# 586        772.0        272.0       1257.0        278.0    37    119  003808
# 587        335.0        114.0        335.0        114.0    37    119  003809
# 588        863.0        194.0        952.0        187.0    37    119  003809
# 589        200.0        152.0        506.0        187.0    37    119  003810
# 590        742.0        200.0        896.0        196.0    37    119  003811
# 591        273.0        108.0        522.0        121.0    37    119  003902
# 592        136.0        116.0        386.0        149.0    37    119  003902
# 593        273.0        137.0        418.0        141.0    37    119  003902
# 594        160.0         76.0        421.0         85.0    37    119  003903
# 595        153.0         83.0        375.0        111.0    37    119  004000
# 596        375.0        150.0        587.0        159.0    37    119  004000
# 597        296.0         94.0        489.0        100.0    37    119  004000
# 598        133.0         82.0        196.0        109.0    37    119  004101
# 599        254.0        204.0        339.0        200.0    37    119  004102
# 600         78.0         54.0        216.0         84.0    37    119  004200
# 601        254.0        141.0        390.0        143.0    37    119  004200
# 602        161.0         79.0        391.0        109.0    37    119  004302
# 603        442.0        142.0        851.0        188.0    37    119  004302
# 604        559.0        108.0        883.0         80.0    37    119  004303
# 605        655.0        157.0       1041.0        150.0    37    119  004304
# 606        375.0        151.0        665.0        167.0    37    119  004306
# 607        357.0        337.0        702.0        349.0    37    119  004306
# 608        126.0         68.0        381.0         90.0    37    119  004400
# 609        332.0         95.0        458.0         83.0    37    119  004400
# 610        177.0         89.0        461.0        129.0    37    119  004500
# 611        149.0         81.0        480.0        250.0    37    119  004500
# 612        277.0        107.0        519.0        118.0    37    119  004600
# 613        265.0        122.0        588.0        163.0    37    119  004600
# 614        134.0         68.0        662.0        188.0    37    119  004800
# 615        190.0         84.0        432.0        113.0    37    119  004800
# 616        184.0         74.0        516.0        118.0    37    119  004800
# 617        175.0         57.0        237.0         63.0    37    119  004900
# 618        239.0         97.0        412.0        109.0    37    119  005000
# 619        406.0        105.0        544.0        111.0    37    119  005000
# 620        159.0         62.0        365.0         76.0    37    119  005100
# 621        208.0         94.0        803.0        212.0    37    119  005100
# 622         54.0         36.0        161.0         54.0    37    119  005200
# 623        107.0         53.0        237.0         62.0    37    119  005200
#
#     block group
# 0             2
# 1             1
# 2             1
# 3             2
# 4             1
# 5             1
# 6             1
# 7             1
# 8             2
# 9             2
# 10            3
# 11            3
# 12            1
# 13            2
# 14            2
# 15            2
# 16            3
# 17            3
# 18            1
# 19            2
# 20            3
# 21            1
# 22            1
# 23            1
# 24            1
# 25            1
# 26            2
# 27            3
# 28            1
# 29            2
# 30            2
# 31            2
# 32            2
# 33            2
# 34            2
# 35            2
# 36            1
# 37            1
# 38            3
# 39            2
# 40            2
# 41            1
# 42            2
# 43            2
# 44            2
# 45            2
# 46            1
# 47            3
# 48            1
# 49            2
# 50            2
# 51            1
# 52            2
# 53            1
# 54            4
# 55            2
# 56            2
# 57            1
# 58            2
# 59            1
# 60            2
# 61            4
# 62            3
# 63            2
# 64            1
# 65            3
# 66            3
# 67            1
# 68            1
# 69            2
# 70            2
# 71            1
# 72            2
# 73            1
# 74            1
# 75            1
# 76            1
# 77            1
# 78            3
# 79            3
# 80            3
# 81            2
# 82            2
# 83            2
# 84            3
# 85            2
# 86            2
# 87            2
# 88            1
# 89            1
# 90            2
# 91            1
# 92            1
# 93            2
# 94            2
# 95            3
# 96            2
# 97            1
# 98            1
# 99            1
# 100           2
# 101           1
# 102           2
# 103           1
# 104           1
# 105           1
# 106           2
# 107           2
# 108           2
# 109           2
# 110           2
# 111           2
# 112           2
# 113           2
# 114           2
# 115           1
# 116           1
# 117           2
# 118           2
# 119           1
# 120           1
# 121           2
# 122           2
# 123           2
# 124           1
# 125           1
# 126           2
# 127           2
# 128           1
# 129           1
# 130           2
# 131           2
# 132           1
# 133           2
# 134           1
# 135           1
# 136           2
# 137           1
# 138           1
# 139           2
# 140           1
# 141           2
# 142           1
# 143           1
# 144           1
# 145           1
# 146           1
# 147           2
# 148           3
# 149           3
# 150           3
# 151           2
# 152           3
# 153           1
# 154           3
# 155           1
# 156           3
# 157           1
# 158           2
# 159           1
# 160           2
# 161           3
# 162           2
# 163           1
# 164           1
# 165           2
# 166           1
# 167           1
# 168           2
# 169           2
# 170           1
# 171           2
# 172           2
# 173           3
# 174           2
# 175           3
# 176           2
# 177           3
# 178           2
# 179           3
# 180           1
# 181           1
# 182           2
# 183           1
# 184           2
# 185           1
# 186           2
# 187           1
# 188           2
# 189           3
# 190           1
# 191           2
# 192           1
# 193           2
# 194           1
# 195           1
# 196           2
# 197           1
# 198           1
# 199           2
# 200           1
# 201           2
# 202           1
# 203           1
# 204           1
# 205           3
# 206           1
# 207           1
# 208           2
# 209           4
# 210           1
# 211           3
# 212           1
# 213           1
# 214           2
# 215           1
# 216           1
# 217           2
# 218           1
# 219           1
# 220           2
# 221           1
# 222           1
# 223           2
# 224           2
# 225           3
# 226           2
# 227           1
# 228           1
# 229           1
# 230           1
# 231           1
# 232           2
# 233           3
# 234           1
# 235           2
# 236           1
# 237           2
# 238           1
# 239           2
# 240           1
# 241           2
# 242           1
# 243           2
# 244           1
# 245           1
# 246           1
# 247           2
# 248           2
# 249           1
# 250           2
# 251           1
# 252           2
# 253           1
# 254           3
# 255           1
# 256           2
# 257           2
# 258           1
# 259           1
# 260           2
# 261           2
# 262           1
# 263           2
# 264           3
# 265           2
# 266           1
# 267           1
# 268           1
# 269           3
# 270           1
# 271           1
# 272           1
# 273           2
# 274           1
# 275           2
# 276           1
# 277           1
# 278           2
# 279           1
# 280           2
# 281           3
# 282           1
# 283           2
# 284           1
# 285           3
# 286           1
# 287           3
# 288           1
# 289           1
# 290           1
# 291           1
# 292           1
# 293           1
# 294           1
# 295           3
# 296           1
# 297           1
# 298           2
# 299           1
# 300           2
# 301           1
# 302           1
# 303           1
# 304           1
# 305           2
# 306           1
# 307           2
# 308           1
# 309           2
# 310           1
# 311           1
# 312           1
# 313           2
# 314           3
# 315           4
# 316           1
# 317           2
# 318           1
# 319           2
# 320           1
# 321           2
# 322           3
# 323           1
# 324           2
# 325           1
# 326           1
# 327           1
# 328           1
# 329           2
# 330           2
# 331           1
# 332           2
# 333           1
# 334           1
# 335           1
# 336           1
# 337           1
# 338           2
# 339           1
# 340           2
# 341           2
# 342           1
# 343           1
# 344           1
# 345           1
# 346           2
# 347           2
# 348           1
# 349           1
# 350           2
# 351           2
# 352           1
# 353           2
# 354           1
# 355           1
# 356           2
# 357           3
# 358           1
# 359           2
# 360           1
# 361           2
# 362           1
# 363           2
# 364           1
# 365           2
# 366           1
# 367           1
# 368           2
# 369           2
# 370           3
# 371           2
# 372           1
# 373           1
# 374           2
# 375           2
# 376           1
# 377           1
# 378           1
# 379           1
# 380           2
# 381           1
# 382           2
# 383           1
# 384           1
# 385           1
# 386           2
# 387           1
# 388           1
# 389           1
# 390           1
# 391           2
# 392           1
# 393           2
# 394           1
# 395           2
# 396           1
# 397           2
# 398           1
# 399           1
# 400           2
# 401           1
# 402           2
# 403           1
# 404           1
# 405           1
# 406           1
# 407           1
# 408           2
# 409           1
# 410           1
# 411           1
# 412           2
# 413           1
# 414           1
# 415           2
# 416           1
# 417           2
# 418           1
# 419           1
# 420           2
# 421           1
# 422           2
# 423           3
# 424           1
# 425           2
# 426           2
# 427           1
# 428           1
# 429           2
# 430           3
# 431           2
# 432           3
# 433           2
# 434           3
# 435           2
# 436           3
# 437           2
# 438           1
# 439           3
# 440           1
# 441           1
# 442           2
# 443           1
# 444           2
# 445           1
# 446           2
# 447           1
# 448           3
# 449           1
# 450           1
# 451           1
# 452           1
# 453           2
# 454           1
# 455           2
# 456           1
# 457           2
# 458           1
# 459           2
# 460           3
# 461           4
# 462           1
# 463           2
# 464           3
# 465           1
# 466           1
# 467           2
# 468           1
# 469           2
# 470           1
# 471           2
# 472           2
# 473           1
# 474           1
# 475           2
# 476           1
# 477           2
# 478           3
# 479           2
# 480           3
# 481           1
# 482           2
# 483           2
# 484           1
# 485           2
# 486           3
# 487           2
# 488           1
# 489           1
# 490           2
# 491           1
# 492           2
# 493           2
# 494           1
# 495           2
# 496           1
# 497           2
# 498           3
# 499           1
# 500           2
# 501           1
# 502           2
# 503           1
# 504           2
# 505           1
# 506           2
# 507           1
# 508           3
# 509           1
# 510           1
# 511           1
# 512           3
# 513           1
# 514           3
# 515           1
# 516           1
# 517           3
# 518           1
# 519           1
# 520           2
# 521           2
# 522           3
# 523           1
# 524           2
# 525           1
# 526           2
# 527           1
# 528           3
# 529           1
# 530           1
# 531           2
# 532           2
# 533           3
# 534           1
# 535           2
# 536           3
# 537           1
# 538           2
# 539           1
# 540           1
# 541           2
# 542           1
# 543           2
# 544           3
# 545           1
# 546           2
# 547           1
# 548           3
# 549           1
# 550           3
# 551           1
# 552           2
# 553           1
# 554           1
# 555           2
# 556           1
# 557           2
# 558           1
# 559           2
# 560           2
# 561           1
# 562           3
# 563           1
# 564           1
# 565           2
# 566           2
# 567           1
# 568           3
# 569           1
# 570           2
# 571           2
# 572           3
# 573           1
# 574           2
# 575           1
# 576           2
# 577           1
# 578           2
# 579           3
# 580           1
# 581           2
# 582           1
# 583           2
# 584           1
# 585           2
# 586           3
# 587           1
# 588           2
# 589           1
# 590           1
# 591           1
# 592           3
# 593           4
# 594           2
# 595           1
# 596           3
# 597           4
# 598           2
# 599           1
# 600           1
# 601           2
# 602           1
# 603           2
# 604           1
# 605           1
# 606           1
# 607           2
# 608           1
# 609           2
# 610           1
# 611           2
# 612           1
# 613           2
# 614           1
# 615           2
# 616           3
# 617           1
# 618           1
# 619           2
# 620           1
# 621           2
# 622           1
# 623           2

# %%
len(Data)
# Out:
# 624

# %% [markdown]
# ### Rename columns with proper names
#
# - Once we get our Data, use use the rename function in pandas to modify the column names for all the variables.

# %%
Data.rename(columns={#########################################SEX BY AGE UNDER #######################################,
                       'B01001_003E':'Male_under_5E','B01001_003M':'Male_under_5M','B01001_004E':'Male_5_to_9E',
                       'B01001_004M':'Male_5_to_9M','B01001_005E':'Male_10_to_14E','B01001_005M':'Male_10_to_14M',
                       'B01001_006E':'Male_15_to_17E','B01001_006M':'Male_15_to_17M','B01001_027E':'Female_under_5E',
                       'B01001_027M':'Female_under_5M','B01001_028E':'Female_5_to_9E','B01001_028M':'Female_5_to_9M',
                       'B01001_029E':'Female_10_to_14E','B01001_029M':'Female_10_to_14M',
                       'B01001_030E':'Female_15_to_17E', 'B01001_030M':'Female_15_to_17M',
                       'B01001_001E':'Sex_By_Age_TotalE','B01001_001M':'Sex_By_Age_TotalM',
                    #######################################SEX BY AGE OVER#############################################,
                     'B01001_020E':'Male_65_to_66E','B01001_020M':'Male_65_to_66M','B01001_021E':'Male_67_to_69E',
                     'B01001_021M':'Male_67_to_69M','B01001_022E':'Male_70_to_74E','B01001_022M':'Male_70_to_74M',
                     'B01001_023E':'Male_75_to_79E','B01001_023M':'Male_75_to_79M','B01001_024E':'Male_80_to_84E',
                     'B01001_024M':'Male_80_to_84M','B01001_025E':'Male_85_and_overE','B01001_025M':'Male_85_and_overM',
                     'B01001_044E':'Female_65_to_66E','B01001_044M':'Female_65_to_66M','B01001_045E':'Female_67_to_69E',
                     'B01001_045M':'Female_67_to_69M','B01001_046E':'Female_70_to_74E','B01001_046M':'Female_70_to_74M',
                     'B01001_047E':'Female_75_to_79E','B01001_047M':'Female_75_to_79M','B01001_048E':'Female_80_to_84E',
                     'B01001_048M':'Female_80_to_84M','B01001_049E':'Female_85_and_overE',
                     'B01001_049M':'Female_85_and_overM',
                     ###################################### MEDIAN AGE ################################################,
                    'B01002_001E': 'Median_AgeE','B01002_001M':'Median_AgeM',
                     ############################## HISPANIC OR LATINO ORIGIN BY RACE ###############################,
                     'B03002_006E':'AsianAloneE','B03002_006M':'AsianAloneM','B03002_004E':'BlackAloneE',
                     'B03002_004M':'BlackAloneM','B03002_003E':'WhiteAloneE','B03002_003M':'WhiteAloneM',
                     'B03002_012E':'HispanicAloneE', 'B03002_012M':'HispanicAloneM','B03002_005E':'AmericanIndianAloneE',
                     'B03002_005M':'AmericanIndianAloneM','B03002_007E':'NativeHawaiianAloneE',
                     'B03002_007M':'NativeHawaiianAloneM','B03002_008E':'SomeOtherRaceAloneE',
                     'B03002_008M':'SomeOtherRaceAloneM','B03002_009E':'TwoorMoreRacesAloneE',
                     'B03002_009M':'TwoorMoreRacesAloneM','B03002_010E':'TwoorMoreRacesIncludingSomeotherRaceAloneE',
                     'B03002_010M':'TwoorMoreRacesIncludingSomeotherRaceAloneM',
                     'B03002_011E':'TwoorMoreRacesExcludingSomeotherRaceAloneE',
                     'B03002_011M':'TwoorMoreRacesExcludingSomeotherRaceAloneM','B03002_001E':'TotalRaceE', 
                     'B03002_001M':'TotalRaceM',
                     ############################### MEANS OF TRANSPORTATION TO WORK ##################################,
                     'B08134_021E':'DroveAloneE','B08134_021M':'DroveAloneM','B08134_001E':'TotalTransportationE',
                     'B08134_001M':'TotalTransportationM','B08134_015E':'Drove_20_to_24E','B08134_015M':'Drove_20_to_24M',
                     'B08134_016E':'Drove_25_to_29E','B08134_016M':'Drove_25_to_29M','B08134_017E':'Drove_30_to_34E',
                     'B08134_017M':'Drove_30_to_34M','B08134_018E':'Drove_35_to_44E','B08134_018M':'Drove_35_to_44M',
                     'B08134_019E':'Drove_45_to_59E','B08134_019M':'Drove_45_to_59M','B08134_020E':"Drove_60_or_MoreE", 
                     'B08134_020M':"Drove_60_or_MoreM",
                     #########################SEX BY ENROLLMENT BY LEVEL OF EDUCATION ##############################,
                     'B14002_009E':'Kindergaten_MaleE','B14002_009M':'Kindergaten_MaleM',
                     'B14002_012E':'Grade_1_to_4_MaleE','B14002_012M':'Grade_1_to_4_MaleM',
                     'B14002_015E':'Grade_5_to_8_MaleE','B14002_015M':'Grade_5_to_8_MaleM',
                     'B14002_018E':'Grade_9_to_12_MaleE','B14002_018M':'Grade_9_to_12_MaleM',
                     'B14002_033E':'Kindergaten_FemaleE', 'B14002_033M':'Kindergaten_FemaleM',
                     'B14002_036E':'Grade_1_to_4_FemaleE','B14002_036M':'Grade_1_to_4_FemaleM',
                     'B14002_039E':'Grade_5_to_8_FemaleE','B14002_039M':'Grade_5_to_8_FemaleM',
                     'B14002_042E':'Grade_9_to_12_FemaleE','B14002_042M':'Grade_9_to_12_FemaleM',
                     'B14002_007E':'Kindergaten_TotalMaleE','B14002_007M':'Kindergaten_TotalMaleM',
                     'B14002_010E':'Grade_1_to_4_TotalMaleE','B14002_010M':'Grade_1_to_4_TotalMaleM',
                     'B14002_013E':'Grade_5_to_8_TotalMaleE', 'B14002_013M':'Grade_5_to_8_TotalMaleM',
                     'B14002_016E':'Grade_9_to_12_TotalMaleE','B14002_016M':'Grade_9_to_12_TotalMaleM',
                     'B14002_031E':'Kindergaten_TotalFemaleE','B14002_031M':'Kindergaten_TotalFemaleM',
                     'B14002_034E':'Grade_1_to_4_TotalFemaleE','B14002_034M':'Grade_1_to_4_TotalFemaleM',
                     'B14002_037E':'Grade_5_to_8_TotalFemaleE','B14002_037M':'Grade_5_to_8_TotalFemaleM',
                     'B14002_040E':'Grade_9_to_12_TotalFemaleE' ,'B14002_040M':'Grade_9_to_12_TotalFemaleM',
                     ##################################EDUCATIONAL ATTAINMENT ############################,
                     'B15003_002E':'NoSchoolingE','B15003_002M':'NoSchoolingM','B15003_017E':'HighSchoolDiplomaE',
                     'B15003_017M':'HighSchoolDiplomaM','B15003_018E':'GEDorAlternativeE',
                     'B15003_018M':'GEDorAlternativeM','B15003_019E':'SomeCollegeLessThan1YearE',
                     'B15003_019M':'SomeCollegeLessThan1YearM','B15003_020E':'SomeCollege1orMoreYearsNoDegreeE',
                     'B15003_020M':'SomeCollege1orMoreYearsNoDegreeM',
                     'B15003_021E':'AssociateDegreeE','B15003_021M':'AssociateDegreeM','B15003_022E':'BachelorsDegreeE',
                     'B15003_022M':'BachelorsDegreeM','B15003_023E':'MastersDegreeE','B15003_023M':'MastersDegreeM',
                     'B15003_024E':'ProfessionalSchoolDegreeE','B15003_024M':'ProfessionalSchoolDegreeM',
                     'B15003_025E':'DoctorateDegreeE','B15003_025M':'DoctorateDegreeM',
                     'B15003_001E':'TotalEducationAttainmentE','B15003_001M':'TotalEducationAttainmentM',
                     ########################################MEDIAN HOUSEHOLDINCOME###################################,
                     'B19013_001E':'MedianHouseholdIncomeE','B19013_001M':'MedianHouseholdIncomeM',
                     ##########################SEX BY AGE BY VETERAN STATUS FOR CIVILIAN POPULATION#########################,
                     'B21001_002E':'VeteranE','B21001_002M':'VeteranM','B21001_001E':'TotalVeteranE',
                     'B21001_001M':'TotalVeteranM',
                     #############################EMPLOYMENT STATUS#################################,
                     'B23025_004E':'CivilianInLaborForceEmployedE','B23025_004M':'CivilianInLaborForceEmployedM',
                     'B23025_002E':'TotalInLaborForceE','B23025_002M':'TotalInLaborForceM',
                     ###########################OCCUPANCY STATUS##############################,
                     'B25002_003E':'VacantE','B25002_003M':'VacantM','B25002_001E':'TotalOccupancyE',
                     'B25002_001M':'TotalOccupancyM','B25002_002E':'OccupiedE','B25002_002M':'OccupiedM',
                     #########################TENURE BY VEHICLE AVAILABLE##########################################,
                     'B25044_010E':'RenterOccupiedNoVehicleE','B25044_010M':'RenterOccupiedNoVehicleM',
                     'B25044_003E':'OwnerOccupiedNoVehicleE','B25044_003M':'OwnerOccupiedNoVehicleM',
                     'B25044_001E':'TotalVehicleByTenureE','B25044_001M':'TotalVehicleByTenureM',
                     ########################GROSS RENT ####################################,
                     'B25063_001E':'TotalGrossRentE','B25063_001M':'TotalGrossRentM',
                     ###################################Owneroccupied####################################
                     'B25003_002E':'OwnerOccupiedE', 'B25003_002M':'OwnerOccupiedM',
                     'B25003_001E':'TotalOwnerOccupiedE', 'B25003_001M':'TotalOwnerOccupiedM',
                     ############################## Internet ##############################################
                     'B28011_004E': 'BroadbandE', 'B28011_004M':'BroadbandM', 'B28011_001E':'TotalBroadbandE'
                     ,'B28011_001M': 'TotalBroadbandM'
                    
                    },
           inplace = True)

# %% [markdown]
# #### Convert variables to integer
#
# - The output of our data from the API is pandas object(string), so we cannot perform mathematical operations on them. Hence we convert the numerical variables to integer

# %%
col = []

for row in Data.columns:
    if row not in ('NAME','GEO_ID','state','county','tract','block group'):
        col.append(row)
        
        
for row in col:
    Data[row]= Data[row].apply(np.int64)
    
# print(Data.dtypes)

# %% [markdown]
# #### Replace Null Values with NA
#
# - Data from the census API which are NaN values shows either as -666666666.0, -222222222.0, or -333333333.0, we search and replace all of them with actual NaNs values using numpy

# %%
Data.replace(-666666666.0,np.nan,inplace= True)
Data.replace(-222222222.0,np.nan,inplace= True)
Data.replace(-333333333.0,np.nan,inplace= True)

# %%
# Data.dtypes

# %% [markdown]
# #### Calculate Margin of Error
#
# - To compute the margin of error, we first square all the Margin of error
# - We target any variable that ends with capital 'M' and square it. In subsequent steps, we will use suffix and prefix to identify sets of variables, here we identify Margin of errors with 'M'

# %%
for row in Data:
    if row.endswith("M"):
        Data[str(row)] = Data[str(row)]**2

# %% [markdown]
# #### Derived Margin of Error
#
# - The first step in calculating the derived margin of error is to sum  the individual squared margin of error of each derived measure. For example, if we want derived margin of error for individuals under 18, we have to sum the squared margin of error for males and females who are under the age of 18
#
#
#
# - For variables which have multiple zero estimates, we are only interested in the first margin or error. We skip everyother margin of error with zero estimates. To do this, we count the number of variables with zero estimates, and sum the count.
#
#
#
#
# - For variables where the sum of count of zero estimates is zero, we keep the sum of the derived margin of error. For those where the sum of count of zero estimates is not zero, we multiple the count by 144 and subtract it from the sum of the margin of error, then add 144.

# %% [markdown]
# ##### Under 18  MOE

# %%
Under18MOE = ['Male_under_5M', 'Male_5_to_9M', 'Male_10_to_14M', 'Male_15_to_17M',
              'Female_under_5M', 'Female_5_to_9M', 'Female_10_to_14M', 'Female_15_to_17M']

Under18E = ['Male_under_5E', 'Male_5_to_9E', 'Male_10_to_14E', 'Male_15_to_17E',
              'Female_under_5E', 'Female_5_to_9E', 'Female_10_to_14E', 'Female_15_to_17E']


Data['Under18MOEZero'] = (Data[Under18E]==0).sum(1)
Data['Under18MOENonZero'] = Data[Under18MOE].sum(1)
Data['Under18MOEN'] = np.where(Data['Under18MOEZero']== 0, Data['Under18MOENonZero'],
                               (Data['Under18MOENonZero']-Data['Under18MOEZero']*144)+144)

Data['SexbyAgeMOED'] = Data['Sex_By_Age_TotalM']

# %% [markdown]
# ##### Over 65 MOE

# %%
Over65MOE = ['Male_65_to_66M', 'Male_67_to_69M', 'Male_70_to_74M', 'Male_75_to_79M', 'Male_80_to_84M',
             'Male_85_and_overM', 'Female_65_to_66M', 'Female_67_to_69M', 'Female_70_to_74M', 'Female_75_to_79M',
             'Female_80_to_84M', 'Female_85_and_overM']


Over65E = ['Male_65_to_66E', 'Male_67_to_69E', 'Male_70_to_74E', 'Male_75_to_79E', 'Male_80_to_84E',
             'Male_85_and_overE', 'Female_65_to_66E', 'Female_67_to_69E', 'Female_70_to_74E', 'Female_75_to_79E',
             'Female_80_to_84E', 'Female_85_and_overE']



Data['Over65MOEZero'] =(Data[Over65E]==0).sum(1)
Data['Over65MOENonZero'] = Data[Over65MOE].sum(1)
Data['Over65MOEN'] = np.where(Data['Over65MOEZero']== 0, Data['Over65MOENonZero'],
                              (Data['Over65MOENonZero']-Data['Over65MOEZero']*144)+144)

# %% [markdown]
# ##### Race MOE

# %%
RaceOtherMOE = ['AmericanIndianAloneM','NativeHawaiianAloneM','SomeOtherRaceAloneM','TwoorMoreRacesAloneM'] #Incuding/Excluding

RaceOtherE = ['AmericanIndianAloneE','NativeHawaiianAloneE','SomeOtherRaceAloneE','TwoorMoreRacesAloneE']


Data['AsianMOEN'] = Data['AsianAloneM']
Data['BlackMOEN'] = Data['BlackAloneM']
Data['WhiteMOEN'] = Data['WhiteAloneM']
Data['HispanicMOEN'] = Data['HispanicAloneM']

Data['OtherMOEZero'] =  (Data[RaceOtherE]==0).sum(1)
Data['OtherMOENonZero'] = Data[RaceOtherMOE].sum(1)
Data['OtherMOEN'] = np.where(Data['OtherMOEZero']== 0,  Data['OtherMOENonZero'],
                              (Data['OtherMOENonZero']-Data['OtherMOEZero']*144)+144)


Data['TotalRaceMOED'] = Data['TotalRaceM']

# %% [markdown]
# ##### Commute Alone MOE

# %%
CommuteMOE = ['Drove_20_to_24M', 'Drove_25_to_29M', 'Drove_30_to_34M', 'Drove_35_to_44M', 
                 'Drove_45_to_59M', 'Drove_60_or_MoreM']

CommuteE = ['Drove_20_to_24E', 'Drove_25_to_29E', 'Drove_30_to_34E', 'Drove_35_to_44E', 
                 'Drove_45_to_59E', 'Drove_60_or_MoreE']


Data['DroveMOEZero'] = (Data[CommuteE]==0).sum(1)
Data['DroveMOENonZero'] = Data[CommuteMOE].sum(1)
Data['DroveMoreThan20MinutesMOEN'] = np.where(Data['DroveMOEZero']== 0, Data['DroveMOENonZero'],
                              (Data['DroveMOENonZero']-Data['DroveMOEZero'] *144)+144)



Data['TotalTransportationMOED'] = Data['TotalTransportationM']

# %% [markdown]
# ##### Private (No School or Pre School) MOE

# %%
PrivateMOE = ['Kindergaten_MaleM','Grade_1_to_4_MaleM','Grade_5_to_8_MaleM','Grade_9_to_12_MaleM',
          'Kindergaten_FemaleM','Grade_1_to_4_FemaleM','Grade_5_to_8_FemaleM','Grade_9_to_12_FemaleM']

PrivateE = ['Kindergaten_MaleE','Grade_1_to_4_MaleE','Grade_5_to_8_MaleE','Grade_9_to_12_MaleE',
          'Kindergaten_FemaleE','Grade_1_to_4_FemaleE','Grade_5_to_8_FemaleE','Grade_9_to_12_FemaleE']


Data['PrivateNoSchoolMOEZero'] =   (Data[PrivateE ]==0).sum(1)
Data['PrivateNoSchoolMOENonZero'] =  Data[PrivateMOE].sum(1)
Data['PrivateNoSchoolMOEN'] = np.where(Data['PrivateNoSchoolMOEZero']== 0,Data['PrivateNoSchoolMOENonZero'],
                              (Data['PrivateNoSchoolMOENonZero'] - Data['PrivateNoSchoolMOEZero'] *144)+144)
##############################################################################################################


PrivateTotalMOE = ['Kindergaten_TotalMaleM','Grade_1_to_4_TotalMaleM','Grade_5_to_8_TotalMaleM',
               'Grade_9_to_12_TotalMaleM','Kindergaten_TotalFemaleM','Grade_1_to_4_TotalFemaleM',
               'Grade_5_to_8_TotalFemaleM','Grade_9_to_12_TotalFemaleM' ]

PrivateTotalE = ['Kindergaten_TotalMaleE','Grade_1_to_4_TotalMaleE','Grade_5_to_8_TotalMaleE',
               'Grade_9_to_12_TotalMaleE','Kindergaten_TotalFemaleE','Grade_1_to_4_TotalFemaleE',
               'Grade_5_to_8_TotalFemaleE','Grade_9_to_12_TotalFemaleE' ]


Data['PrivateNoSchoolTotalMOEDZero'] =  (Data[PrivateTotalE]==0).sum(1)
Data['PrivateNoSchoolTotalMOEDNonZero'] =  Data[PrivateTotalMOE].sum(1)
Data['PrivateNoSchoolTotalMOED'] = np.where(Data['PrivateNoSchoolTotalMOEDZero']== 0, Data['PrivateNoSchoolTotalMOEDNonZero'],
                              (Data['PrivateNoSchoolTotalMOEDNonZero'] - Data['PrivateNoSchoolTotalMOEDZero'] *144)+144)

# %% [markdown]
# ##### Adults With High School Diploma MOE

# %%
HighschoolMOE = ['HighSchoolDiplomaM','GEDorAlternativeM','SomeCollegeLessThan1YearM',
              'SomeCollege1orMoreYearsNoDegreeM','AssociateDegreeM','BachelorsDegreeM',
             'MastersDegreeM','ProfessionalSchoolDegreeM','DoctorateDegreeM']



HighschoolE = ['HighSchoolDiplomaE','GEDorAlternativeE','SomeCollegeLessThan1YearE',
              'SomeCollege1orMoreYearsNoDegreeE','AssociateDegreeE','BachelorsDegreeE',
             'MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE']                        #Takeout Noschooling?

Data['HighSchoolDiplomaMOEZero'] = (Data[HighschoolE]==0).sum(1)
Data['HighSchoolDiplomaMOENonZero'] = Data[HighschoolMOE].sum(1)
Data['HighSchoolDiplomaMOEN'] = np.where(Data['HighSchoolDiplomaMOEZero']== 0, Data['HighSchoolDiplomaMOENonZero'],
                              (Data['HighSchoolDiplomaMOENonZero']-Data['HighSchoolDiplomaMOEZero']*144)+144)
                                                                        
Data['TotalEducationAttainmentMOED'] = Data['TotalEducationAttainmentM']

# %% [markdown]
# ##### Adults with At Least Bachelors Degrees MOE

# %%
BachelorsMOE = ['BachelorsDegreeM','MastersDegreeM','ProfessionalSchoolDegreeM','DoctorateDegreeM']
BachelorsE = ['BachelorsDegreeE','MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE']


Data['AdultsWithAtLeastBachelorsMOEZero'] = (Data[BachelorsE ]==0).sum(1)
Data['AdultsWithAtLeastBachelorsMOENonZero'] = Data[BachelorsMOE].sum(1)
Data['AdultsWithAtLeastBachelorsMOEN'] = np.where(Data['AdultsWithAtLeastBachelorsMOEZero']== 0, 
                                                  Data['AdultsWithAtLeastBachelorsMOENonZero'],
                                                  ( Data['AdultsWithAtLeastBachelorsMOENonZero']-
                                                   Data['AdultsWithAtLeastBachelorsMOEZero'] *144)+144)
                                      

Data['TotalEducationAttainmentMOED'] = Data['TotalEducationAttainmentM']

# %% [markdown]
# #### Drove Alone

# %%
Data['DroveAloneMOEN'] = Data['DroveAloneM']
Data['TotalTransportationMOED'] = Data['TotalTransportationM']

# %% [markdown]
# ##### Veteran MOE

# %%
Data['VeteranMOEN'] = Data['VeteranM']
Data['TotalVeteranMOED'] = Data['TotalVeteranM']

# %% [markdown]
# ##### Unemployment MOE

# %%
Data['EmployedMOEN'] = Data['CivilianInLaborForceEmployedM']
Data['TotalInLaborForceMOED'] = Data['TotalInLaborForceM']

# %% [markdown]
# ##### Vacancy  MOE

# %%
Data['VacantMOEN'] = Data['VacantM']
Data['TotalOccupancyMOED'] = Data['TotalOccupancyM']

# %% [markdown]
# #####  Occupied  MOE

# %%
Data['OccupiedMOEN'] = Data['OccupiedM']
Data['TotalOccupancyMOED'] = Data['TotalOccupancyM']

# %% [markdown]
# #### Owner Occupied

# %%
Data['OwnerOccupiedMOEN'] = Data['OwnerOccupiedM']
Data['TotalOwnerOccupiedMOED'] = Data['TotalOwnerOccupiedM']

# %% [markdown]
# #### Internet Access

# %%
Data['BroadbandMOEN'] = Data['BroadbandM']
Data['TotalBroadbandMOED'] = Data['TotalBroadbandM']

# %% [markdown]
# #### Gross Rent

# %%
# Data['GrossRentMOEN'] = Data['TotalGrossRentM']

# %% [markdown]
# #### Median Household Income

# %%
# Data['MedianHouseholdIncomeMOEN'] = Data['MedianHouseholdIncomeM']

# %% [markdown]
# #### Median Age

# %%
# Data['MedianAgeMOEN'] = Data['Median_AgeM']

# %% [markdown]
# ###### No Vehicle MOE

# %%
NoVehicleMOE = ['RenterOccupiedNoVehicleM','OwnerOccupiedNoVehicleM']
NoVehicleE = ['RenterOccupiedNoVehicleE','OwnerOccupiedNoVehicleE']

Data['NoVehicleMOEZero'] =(Data[NoVehicleE]==0).sum(1)
Data['NoVehicleMOENonZero'] = Data[NoVehicleMOE].sum(1)
Data['NoVehicleMOEN'] = np.where(Data['NoVehicleMOEZero']== 0, Data['NoVehicleMOENonZero'],
                              (Data['NoVehicleMOENonZero']-Data['NoVehicleMOEZero']*144)+144)
                                                                      
                   
Data['TotalVehicleByTenureMOED'] = Data['TotalVehicleByTenureM']

# %% [markdown]
# #### Join BlockGroup Data to NPA data
#
# - After calculating the derived margins of error, we join the output to NPA data using GEOID
#
# - To create GEOID from the ACS Data, we combine the state ID, the County ID, the Census Tract ID and the Block Group ID, and use astype to makesure the data type is an integer since the NPA GEOID2 is an integer data type

# %%
Data['GEOID'] = (Data['state'] + Data['county'] + Data['tract'] + Data['block group']).astype('int64')

# %% [markdown]
# - Read NPA Crosswalkdata. This is on github that is why it is a weblink

# %%
# NPA = pd.read_csv('https://raw.githubusercontent.com/MLProject20/Data/main/NPA_Census_Crosswalk.csv')
# NPA

# %%
NPA = pd.read_csv('https://raw.githubusercontent.com/MLProject20/Data/main/NPA_Census_Crosswalk_2020.csv')

# %%
NPA
# Out:
#            GEOID2       NAMELSAD  NPA
# 0    371190015082  Block Group 2  325
# 1    371190056151  Block Group 1  296
# 2    371190038081  Block Group 1   79
# 3    371190015091  Block Group 1  271
# 4    371190015101  Block Group 1   17
# 5    371190062122  Block Group 2  416
# 6    371190062102  Block Group 2  421
# 7    371190055133  Block Group 3  252
# 8    371190055223  Block Group 3  274
# 9    371190055113  Block Group 3  279
# 10   371190055101  Block Group 1  280
# 11   371190055111  Block Group 1  281
# 12   371190039031  Block Group 1  306
# 13   371199802001  Block Group 1  285
# 14   371190058481  Block Group 1  380
# 15   371190030121  Block Group 1  236
# 16   371190055081  Block Group 1   38
# 17   371190058302  Block Group 2  261
# 18   371190019181  Block Group 1   16
# 19   371190058461  Block Group 1  379
# 20   371190058161  Block Group 1  262
# 21   371190056191  Block Group 1  360
# 22   371190019113  Block Group 3   91
# 23   371190015043  Block Group 3  327
# 24   371190040002  Block Group 2  124
# 25   371190058171  Block Group 1   29
# 26   371190055102  Block Group 2  117
# 27   371190058462  Block Group 2  379
# 28   371190019211  Block Group 1  186
# 29   371190044002  Block Group 2  158
# 30   371190030131  Block Group 1  201
# 31   371190057101  Block Group 1  442
# 32   371190042003  Block Group 3    6
# 33   371190030081  Block Group 1  177
# 34   371190058473  Block Group 3  149
# 35   371190054032  Block Group 2  150
# 36   371199803001  Block Group 1  476
# 37   371190058292  Block Group 2  298
# 38   371190056122  Block Group 2  299
# 39   371190058271  Block Group 1  142
# 40   371190019202  Block Group 2  180
# 41   371190059151  Block Group 1   92
# 42   371190059161  Block Group 1   93
# 43   371190059162  Block Group 2   94
# 44   371190064032  Block Group 2  468
# 45   371190016082  Block Group 2  168
# 46   371190058362  Block Group 2  443
# 47   371190058361  Block Group 1  444
# 48   371190058282  Block Group 2  297
# 49   371190058291  Block Group 1  300
# 50   371190030122  Block Group 2  302
# 51   371190030082  Block Group 2  303
# 52   371190053082  Block Group 2  304
# 53   371190061031  Block Group 1  109
# 54   371190058482  Block Group 2  380
# 55   371190058472  Block Group 2  148
# 56   371190055192  Block Group 2  195
# 57   371190019172  Block Group 2  220
# 58   371190058432  Block Group 2  204
# 59   371190058333  Block Group 3  456
# 60   371190057151  Block Group 1  396
# 61   371190058301  Block Group 1   41
# 62   371190064041  Block Group 1  469
# 63   371190031081  Block Group 1   12
# 64   371190031062  Block Group 2  105
# 65   371190031023  Block Group 3  106
# 66   371190060092  Block Group 2  332
# 67   371190062092  Block Group 2  397
# 68   371190021002  Block Group 2  394
# 69   371190058431  Block Group 1  170
# 70   371190058162  Block Group 2  171
# 71   371190058452  Block Group 2  172
# 72   371190057161  Block Group 1  131
# 73   371190019203  Block Group 3  134
# 74   371190058331  Block Group 1  457
# 75   371190030163  Block Group 3  206
# 76   371190030171  Block Group 1  351
# 77   371190056213  Block Group 3  225
# 78   371190032031  Block Group 1   13
# 79   371190032032  Block Group 2  226
# 80   371190043042  Block Group 2  173
# 81   371190062142  Block Group 2  445
# 82   371190062141  Block Group 1  446
# 83   371190027021  Block Group 1  392
# 84   371190032041  Block Group 1  357
# 85   371190032042  Block Group 2  357
# 86   371190056212  Block Group 2  228
# 87   371190062091  Block Group 1  398
# 88   371190062093  Block Group 3  399
# 89   371190056102  Block Group 2   46
# 90   371190056091  Block Group 1   60
# 91   371190056101  Block Group 1   61
# 92   371190056042  Block Group 2   62
# 93   371190029051  Block Group 1  208
# 94   371190029033  Block Group 3  210
# 95   371190055151  Block Group 1  372
# 96   371190038071  Block Group 1  212
# 97   371190055172  Block Group 2  372
# 98   371190055171  Block Group 1  372
# 99   371190055191  Block Group 1  372
# 100  371190056111  Block Group 1  155
# 101  371190057131  Block Group 1  403
# 102  371190030152  Block Group 2  175
# 103  371190058151  Block Group 1  181
# 104  371199801001  Block Group 1  122
# 105  371190012003  Block Group 3  378
# 106  371190056161  Block Group 1   48
# 107  371190049001  Block Group 1  182
# 108  371190024001  Block Group 1  367
# 109  371190060081  Block Group 1  376
# 110  371190039021  Block Group 1  321
# 111  371190048002  Block Group 2  374
# 112  371190058332  Block Group 2  400
# 113  371190058321  Block Group 1  194
# 114  371190058172  Block Group 2   25
# 115  371190012001  Block Group 1  314
# 116  371190019201  Block Group 1  202
# 117  371190030061  Block Group 1   31
# 118  371190058262  Block Group 2  368
# 119  371190055222  Block Group 2   14
# 120  371190059081  Block Group 1  130
# 121  371190052001  Block Group 1  369
# 122  371190016032  Block Group 2  389
# 123  371190058342  Block Group 2  460
# 124  371190058241  Block Group 1  116
# 125  371190058281  Block Group 1  129
# 126  371190042002  Block Group 2  293
# 127  371190058341  Block Group 1  460
# 128  371190040001  Block Group 1  124
# 129  371190064033  Block Group 3  475
# 130  371190056041  Block Group 1  219
# 131  371190016092  Block Group 2  197
# 132  371190030062  Block Group 2   42
# 133  371190057142  Block Group 2  454
# 134  371190058471  Block Group 1  380
# 135  371190015072  Block Group 2  102
# 136  371190019183  Block Group 3  135
# 137  371190057102  Block Group 2  144
# 138  371190019171  Block Group 1  145
# 139  371190058391  Block Group 1  233
# 140  371190038082  Block Group 2   71
# 141  371190016071  Block Group 1  127
# 142  371190019193  Block Group 3   16
# 143  371190057162  Block Group 2   27
# 144  371190059101  Block Group 1   77
# 145  371190060082  Block Group 2  376
# 146  371190060091  Block Group 1  348
# 147  371190017024  Block Group 4  164
# 148  371190016062  Block Group 2  389
# 149  371190016061  Block Group 1  389
# 150  371190016091  Block Group 1  167
# 151  371190056182  Block Group 2  242
# 152  371190018021  Block Group 1  390
# 153  371190015083  Block Group 3  247
# 154  371190015071  Block Group 1  249
# 155  371190056181  Block Group 1  324
# 156  371190019161  Block Group 1  146
# 157  371190057143  Block Group 3  425
# 158  371190057132  Block Group 2  455
# 159  371190061051  Block Group 1  266
# 160  371190051002  Block Group 2  363
# 161  371190052002  Block Group 2  369
# 162  371190052003  Block Group 3  157
# 163  371190042004  Block Group 4    6
# 164  371190053081  Block Group 1  101
# 165  371190053071  Block Group 1  291
# 166  371190054031  Block Group 1  237
# 167  371190054042  Block Group 2  238
# 168  371190054041  Block Group 1  160
# 169  371190043031  Block Group 1  140
# 170  371190053011  Block Group 1   21
# 171  371190053051  Block Group 1  371
# 172  371190031021  Block Group 1    8
# 173  371190031022  Block Group 2  393
# 174  371190031051  Block Group 1   19
# 175  371190025001  Block Group 1  367
# 176  371190025002  Block Group 2  367
# 177  371190026001  Block Group 1  163
# 178  371190027012  Block Group 2  392
# 179  371190027011  Block Group 1  392
# 180  371190027013  Block Group 3  392
# 181  371190053052  Block Group 2  371
# 182  371190043021  Block Group 1  385
# 183  371190043022  Block Group 2  385
# 184  371190043023  Block Group 3  385
# 185  371190044001  Block Group 1  141
# 186  371190045001  Block Group 1  292
# 187  371190019222  Block Group 2  323
# 188  371190028003  Block Group 3  364
# 189  371190027022  Block Group 2  392
# 190  371190027023  Block Group 3  392
# 191  371190028001  Block Group 1  364
# 192  371190028002  Block Group 2  392
# 193  371190055082  Block Group 2  276
# 194  371190055112  Block Group 2  278
# 195  371190055221  Block Group 1   14
# 196  371190055122  Block Group 2  282
# 197  371190055121  Block Group 1  305
# 198  371190058451  Block Group 1  308
# 199  371190058401  Block Group 1  253
# 200  371190062121  Block Group 1  417
# 201  371190062111  Block Group 1  418
# 202  371190062112  Block Group 2  419
# 203  371190062101  Block Group 1  420
# 204  371190061032  Block Group 2  110
# 205  371190055123  Block Group 3  283
# 206  371190058351  Block Group 1  432
# 207  371190058483  Block Group 3  433
# 208  371190055201  Block Group 1  152
# 209  371190057122  Block Group 2  402
# 210  371190064072  Block Group 2  467
# 211  371190057121  Block Group 1  401
# 212  371190058261  Block Group 1  368
# 213  371190056211  Block Group 1   26
# 214  371190057141  Block Group 1  423
# 215  371190057091  Block Group 1  395
# 216  371190056192  Block Group 2  360
# 217  371190056172  Block Group 2  243
# 218  371190056171  Block Group 1  244
# 219  371190015102  Block Group 2   17
# 220  371190058283  Block Group 3   74
# 221  371190030162  Block Group 2  205
# 222  371190019102  Block Group 2  316
# 223  371190056043  Block Group 3   62
# 224  371190064071  Block Group 1  411
# 225  371190058112  Block Group 2   36
# 226  371190058152  Block Group 2   56
# 227  371190060051  Block Group 1   73
# 228  371190059131  Block Group 1  313
# 229  371190059132  Block Group 2   95
# 230  371190059181  Block Group 1  289
# 231  371190061091  Block Group 1  260
# 232  371190061082  Block Group 2  196
# 233  371190062081  Block Group 1  448
# 234  371190064031  Block Group 1  473
# 235  371190008002  Block Group 2  200
# 236  371190009001  Block Group 1  386
# 237  371190012002  Block Group 2   87
# 238  371190013001  Block Group 1   10
# 239  371190013002  Block Group 2   10
# 240  371190013003  Block Group 3    9
# 241  371190006002  Block Group 2  476
# 242  371190007001  Block Group 1   22
# 243  371190008001  Block Group 1   37
# 244  371190009002  Block Group 2  386
# 245  371190010001  Block Group 1  378
# 246  371190010002  Block Group 2  378
# 247  371190010003  Block Group 3  378
# 248  371190011001  Block Group 1  184
# 249  371190014001  Block Group 1  344
# 250  371190014002  Block Group 2  343
# 251  371190062221  Block Group 1  450
# 252  371190062191  Block Group 1  449
# 253  371190062181  Block Group 1  409
# 254  371190064112  Block Group 2  458
# 255  371190054051  Block Group 1  125
# 256  371190062161  Block Group 1  470
# 257  371190063091  Block Group 1  463
# 258  371190037022  Block Group 2   30
# 259  371190004011  Block Group 1    3
# 260  371190060141  Block Group 1  136
# 261  371190001021  Block Group 1  476
# 262  371190029091  Block Group 1  358
# 263  371190019272  Block Group 2  248
# 264  371190055342  Block Group 2   65
# 265  371190060131  Block Group 1  156
# 266  371190055321  Block Group 1   67
# 267  371190062202  Block Group 2  410
# 268  371190062211  Block Group 1  447
# 269  371190033021  Block Group 1  381
# 270  371190020061  Block Group 1  235
# 271  371190034021  Block Group 1   11
# 272  371190022021  Block Group 1   28
# 273  371190022022  Block Group 2   18
# 274  371190020051  Block Group 1  193
# 275  371190022011  Block Group 1   18
# 276  371190058602  Block Group 2  189
# 277  371190019261  Block Group 1  245
# 278  371190060152  Block Group 2  330
# 279  371190059102  Block Group 2   77
# 280  371190059183  Block Group 3  289
# 281  371190030211  Block Group 1   44
# 282  371190059152  Block Group 2   92
# 283  371190038101  Block Group 1   54
# 284  371190030202  Block Group 2  375
# 285  371190058113  Block Group 3   36
# 286  371190038102  Block Group 2  230
# 287  371190029103  Block Group 3  358
# 288  371190057192  Block Group 2  407
# 289  371190011003  Block Group 3  315
# 290  371190058551  Block Group 1  188
# 291  371190058552  Block Group 2  187
# 292  371190059182  Block Group 2  289
# 293  371190059291  Block Group 1   82
# 294  371190057181  Block Group 1  431
# 295  371190055262  Block Group 2  250
# 296  371190059311  Block Group 1   97
# 297  371190059312  Block Group 2   97
# 298  371190030203  Block Group 3  375
# 299  371190011002  Block Group 2  315
# 300  371190019253  Block Group 3  165
# 301  371190056271  Block Group 1  229
# 302  371190058671  Block Group 1  430
# 303  371190059301  Block Group 1   68
# 304  371190030212  Block Group 2  143
# 305  371190058651  Block Group 1  288
# 306  371190059133  Block Group 3  319
# 307  371190064082  Block Group 2  471
# 308  371190059272  Block Group 2   96
# 309  371190020052  Block Group 2   47
# 310  371190019271  Block Group 1  270
# 311  371190029102  Block Group 2  358
# 312  371190059231  Block Group 1  111
# 313  371190022012  Block Group 2  320
# 314  371190043061  Block Group 1  199
# 315  371190043062  Block Group 2  199
# 316  371190060132  Block Group 2  156
# 317  371190055203  Block Group 3  153
# 318  371190033022  Block Group 2  381
# 319  371190034023  Block Group 3    3
# 320  371190061132  Block Group 2   72
# 321  371190030221  Block Group 1  213
# 322  371190038091  Block Group 1  307
# 323  371190005021  Block Group 1  476
# 324  371190058571  Block Group 1   75
# 325  371190059201  Block Group 1   83
# 326  371190019241  Block Group 1   50
# 327  371190062172  Block Group 2  474
# 328  371190056112  Block Group 2  155
# 329  371190055281  Block Group 1  264
# 330  371190056272  Block Group 2  227
# 331  371190060162  Block Group 2  190
# 332  371190058531  Block Group 1  354
# 333  371190038083  Block Group 3   71
# 334  371190056232  Block Group 2   64
# 335  371190056121  Block Group 1  301
# 336  371190058641  Block Group 1  115
# 337  371190055251  Block Group 1  232
# 338  371190058631  Block Group 1  151
# 339  371190001012  Block Group 2  476
# 340  371190061121  Block Group 1  191
# 341  371190055202  Block Group 2  153
# 342  371190063081  Block Group 1  464
# 343  371190057182  Block Group 2  436
# 344  371190055301  Block Group 1  154
# 345  371190056221  Block Group 1   64
# 346  371190056092  Block Group 2   60
# 347  371190062231  Block Group 1  466
# 348  371190029071  Block Group 1  349
# 349  371190058591  Block Group 1  255
# 350  371190061152  Block Group 2  207
# 351  371190059271  Block Group 1   96
# 352  371190062241  Block Group 1  422
# 353  371190055351  Block Group 1   33
# 354  371190058612  Block Group 2   20
# 355  371190058553  Block Group 3  356
# 356  371190063061  Block Group 1  452
# 357  371190064081  Block Group 1  471
# 358  371190062222  Block Group 2  450
# 359  371190058611  Block Group 1   20
# 360  371190058453  Block Group 3  172
# 361  371190061122  Block Group 2   72
# 362  371190003022  Block Group 2    3
# 363  371190003021  Block Group 1    3
# 364  371190057231  Block Group 1  107
# 365  371190030192  Block Group 2   43
# 366  371190019251  Block Group 1  183
# 367  371190056273  Block Group 3  229
# 368  371190059261  Block Group 1  256
# 369  371190058111  Block Group 1  318
# 370  371190029081  Block Group 1  217
# 371  371190041012  Block Group 2  361
# 372  371190059232  Block Group 2  111
# 373  371190020072  Block Group 2   23
# 374  371190057191  Block Group 1  428
# 375  371190059292  Block Group 2   81
# 376  371190037012  Block Group 2  338
# 377  371190001031  Block Group 1  476
# 378  371190060142  Block Group 2  337
# 379  371190034012  Block Group 2    3
# 380  371190034022  Block Group 2    3
# 381  371190030222  Block Group 2  359
# 382  371190029082  Block Group 2  216
# 383  371190037021  Block Group 1   30
# 384  371190031113  Block Group 3  393
# 385  371190029101  Block Group 1  133
# 386  371190055341  Block Group 1   66
# 387  371190061131  Block Group 1  191
# 388  371190055173  Block Group 3  372
# 389  371190033011  Block Group 1  381
# 390  371190055361  Block Group 1  334
# 391  371190061151  Block Group 1  207
# 392  371190058532  Block Group 2   32
# 393  371190020081  Block Group 1  391
# 394  371190038092  Block Group 2  307
# 395  371190056252  Block Group 2  377
# 396  371190056222  Block Group 2   64
# 397  371190037011  Block Group 1  338
# 398  371190001041  Block Group 1  476
# 399  371190063111  Block Group 1  412
# 400  371190034011  Block Group 1    3
# 401  371190004021  Block Group 1  339
# 402  371190061141  Block Group 1  209
# 403  371190031111  Block Group 1  393
# 404  371190058672  Block Group 2  430
# 405  371190058491  Block Group 1  335
# 406  371190063101  Block Group 1  462
# 407  371190055352  Block Group 2  259
# 408  371190055362  Block Group 2  329
# 409  371190058512  Block Group 2  310
# 410  371190058662  Block Group 2  272
# 411  371190006001  Block Group 1  476
# 412  371190030201  Block Group 1  241
# 413  371190007002  Block Group 2   22
# 414  371190058601  Block Group 1  356
# 415  371190031112  Block Group 2  132
# 416  371190055193  Block Group 3  372
# 417  371190030083  Block Group 3   55
# 418  371190048003  Block Group 3  311
# 419  371190029052  Block Group 2   69
# 420  371190029031  Block Group 1    4
# 421  371190029032  Block Group 2    7
# 422  371190055132  Block Group 2  265
# 423  371190038051  Block Group 1  178
# 424  371190038072  Block Group 2   53
# 425  371190039032  Block Group 2  114
# 426  371190039022  Block Group 2  120
# 427  371190039023  Block Group 3  294
# 428  371190039024  Block Group 4  159
# 429  371190040003  Block Group 3  387
# 430  371190045002  Block Group 2   88
# 431  371190045003  Block Group 3  382
# 432  371190046001  Block Group 1   70
# 433  371190031092  Block Group 2   12
# 434  371190030132  Block Group 2  353
# 435  371190056131  Block Group 1  192
# 436  371190030172  Block Group 2  263
# 437  371190030181  Block Group 1  269
# 438  371190030151  Block Group 1  222
# 439  371190030153  Block Group 3  118
# 440  371190030161  Block Group 1  352
# 441  371190031052  Block Group 2   19
# 442  371190031061  Block Group 1  383
# 443  371190031091  Block Group 1  185
# 444  371190031082  Block Group 2  383
# 445  371190032011  Block Group 1   24
# 446  371190046002  Block Group 2   85
# 447  371190047001  Block Group 1  382
# 448  371190048001  Block Group 1  374
# 449  371190020041  Block Group 1  373
# 450  371190019232  Block Group 2  322
# 451  371190050001  Block Group 1  295
# 452  371190050002  Block Group 2  126
# 453  371190051001  Block Group 1  363
# 454  371190032012  Block Group 2   13
# 455  371190032043  Block Group 3   11
# 456  371190035001  Block Group 1    3
# 457  371190035002  Block Group 2    3
# 458  371190036001  Block Group 1  388
# 459  371190036002  Block Group 2  388
# 460  371190036003  Block Group 3  326
# 461  371190036004  Block Group 4  317
# 462  371190019103  Block Group 3   58
# 463  371190019111  Block Group 1   89
# 464  371190019112  Block Group 2  268
# 465  371190053053  Block Group 3  371
# 466  371190053061  Block Group 1  371
# 467  371190053062  Block Group 2  371
# 468  371190053072  Block Group 2  103
# 469  371190020042  Block Group 2  373
# 470  371190020043  Block Group 3  161
# 471  371190019221  Block Group 1  162
# 472  371190019231  Block Group 1   59
# 473  371190021001  Block Group 1  394
# 474  371190023001  Block Group 1  370
# 475  371190023002  Block Group 2  370
# 476  371190024002  Block Group 2  367
# 477  371190024003  Block Group 3  367
# 478  371190038021  Block Group 1  362
# 479  371190038022  Block Group 2  362
# 480  371190038023  Block Group 3  290
# 481  371190043041  Block Group 1  346
# 482  371190040004  Block Group 4  387
# 483  371190042001  Block Group 1    5
# 484  371190060052  Block Group 2   73
# 485  371190054062  Block Group 2  139
# 486  371190054061  Block Group 1  123
# 487  371190055322  Block Group 2   80
# 488  371190058642  Block Group 2  115
# 489  371190055343  Block Group 3   66
# 490  371190020082  Block Group 2   15
# 491  371190019262  Block Group 2  246
# 492  371190020071  Block Group 1  391
# 493  371190020083  Block Group 3   15
# 494  371190057212  Block Group 2  408
# 495  371190057211  Block Group 1  435
# 496  371190059211  Block Group 1   45
# 497  371190003011  Block Group 1    3
# 498  371190062201  Block Group 1  424
# 499  371190061142  Block Group 2  209
# 500  371190041011  Block Group 1  361
# 501  371190005032  Block Group 2  476
# 502  371190054052  Block Group 2  125
# 503  371190058242  Block Group 2  116
# 504  371190041021  Block Group 1  347
# 505  371190004022  Block Group 2  339
# 506  371190058681  Block Group 1  453
# 507  371190055311  Block Group 1  336
# 508  371190005011  Block Group 1  476
# 509  371190055312  Block Group 2  336
# 510  371190061101  Block Group 1  345
# 511  371190056251  Block Group 1  377
# 512  371190029083  Block Group 3  198
# 513  371190019252  Block Group 2  166
# 514  371190015052  Block Group 2  234
# 515  371190056231  Block Group 1  221
# 516  371190059192  Block Group 2  286
# 517  371190061112  Block Group 2   49
# 518  371190055364  Block Group 4  328
# 519  371190060122  Block Group 2  119
# 520  371190016033  Block Group 3  389
# 521  371190055103  Block Group 3  117
# 522  371190062082  Block Group 2  448
# 523  371190061102  Block Group 2  113
# 524  371190064102  Block Group 2  405
# 525  371190064101  Block Group 1  405
# 526  371190055282  Block Group 2  275
# 527  371190062171  Block Group 1  472
# 528  371190055261  Block Group 1  277
# 529  371190058541  Block Group 1  355
# 530  371190058392  Block Group 2  233
# 531  371190060151  Block Group 1  348
# 532  371190060111  Block Group 1   34
# 533  371190044003  Block Group 3  158
# 534  371190058511  Block Group 1  309
# 535  371190061111  Block Group 1  112
# 536  371190055331  Block Group 1  254
# 537  371190061103  Block Group 3  113
# 538  371190058492  Block Group 2  335
# 539  371190005012  Block Group 2  476
# 540  371190058663  Block Group 3  287
# 541  371190058661  Block Group 1  287
# 542  371190058501  Block Group 1  284
# 543  371190057201  Block Group 1  406
# 544  371190058521  Block Group 1  224
# 545  371190060121  Block Group 1  333
# 546  371190059321  Block Group 1   78
# 547  371190038052  Block Group 2  178
# 548  371190058632  Block Group 2  151
# 549  371190020062  Block Group 2  179
# 550  371190059251  Block Group 1   76
# 551  371190056261  Block Group 1   98
# 552  371190055271  Block Group 1  218
# 553  371190006003  Block Group 3  476
# 554  371190043071  Block Group 1  258
# 555  371190059202  Block Group 2   84
# 556  371190060161  Block Group 1  137
# 557  371190055302  Block Group 2  231
# 558  371190041022  Block Group 2   51
# 559  371190064091  Block Group 1  438
# 560  371190059281  Block Group 1  174
# 561  371190063051  Block Group 1  434
# 562  371190030191  Block Group 1  215
# 563  371190059191  Block Group 1   35
# 564  371190056241  Block Group 1  273
# 565  371190033012  Block Group 2  381
# 566  371190059134  Block Group 4  319
# 567  371190001022  Block Group 2  476
# 568  371190001011  Block Group 1  476
# 569  371190058582  Block Group 2  257
# 570  371190038111  Block Group 1  121
# 571  371190055291  Block Group 1  231
# 572  371190031101  Block Group 1  393
# 573  371190055363  Block Group 3  331
# 574  371190059241  Block Group 1  267
# 575  371190059222  Block Group 2  203
# 576  371190005031  Block Group 1  476
# 577  371190059242  Block Group 2  267
# 578  371190063071  Block Group 1  437
# 579  371190029072  Block Group 2  350
# 580  371190059221  Block Group 1   45
# 581  371190064111  Block Group 1  404
# 582  371190059262  Block Group 2  256
# 583  371190030223  Block Group 3  359
# 584  371190058621  Block Group 1  176
# 585  371190058561  Block Group 1  169
# 586  371190058581  Block Group 1  257
# 587  371190063072  Block Group 2  437
# 588  371190063112  Block Group 2  413
# 589  371190064043  Block Group 3  451
# 590  371190057232  Block Group 2  108
# 591  371190055252  Block Group 2  232
# 592  371190057221  Block Group 1  459
# 593  371190057092  Block Group 2  426
# 594  371190061081  Block Group 1  211
# 595  371190053012  Block Group 2  138
# 596  371190055161  Block Group 1  372
# 597  371190055131  Block Group 1  251
# 598  371190015073  Block Group 3  312
# 599  371190015081  Block Group 1   39
# 600  371190015041  Block Group 1   40
# 601  371190015042  Block Group 2  223
# 602  371190019182  Block Group 2   16
# 603  371190019192  Block Group 2   16
# 604  371190019191  Block Group 1   57
# 605  371190019101  Block Group 1  316
# 606  371190015051  Block Group 1  234
# 607  371190015092  Block Group 2  100
# 608  371190016051  Block Group 1   90
# 609  371190016031  Block Group 1  389
# 610  371190016081  Block Group 1  128
# 611  371190017011  Block Group 1    2
# 612  371190017012  Block Group 2   86
# 613  371190017021  Block Group 1  164
# 614  371190017022  Block Group 2  365
# 615  371190017023  Block Group 3  365
# 616  371190018022  Block Group 2  240
# 617  371190018012  Block Group 2  366
# 618  371190018011  Block Group 1  366
# 619  371190018013  Block Group 3    2
# 620  371190019141  Block Group 1   52
# 621  371190019142  Block Group 2   99
# 622  371190019162  Block Group 2  147
# 623  371190064042  Block Group 2  451

# %%
#Check if all GEOIDs are present

a = list(Data['GEOID'])
b = list(NPA['GEOID2'])
unmatch = list(set(a).difference(b))
len(unmatch)
# Out:
# 0

# %% [markdown]
# ##### Join Data using the common field GEOID

# %%
NPAData = pd.merge(NPA,Data, how = "left", left_on = ['GEOID2'], right_on= ['GEOID'])

# %%
len(NPAData)
# Out:
# 624

# %%
Data = NPAData.groupby('NPA').sum()

# %% [markdown]
# #### Derived Estimates and MOE
#
# - This steps aggregate estimates for derived proportions and also calculate the margin of error for each derived proportion
#
# - We used the aggregated estimates to create derived proportions
#
# - We then aggregate the numerator and the denominator margin of error for each of the derived proportions (We are supposed to square before we aggregate but we have already done that in the step aboved when we were calculating the Margin of error for the estimates)

# %% [markdown]
# ##### Under 18

# %%
Under18E = ['Male_under_5E', 'Male_5_to_9E', 'Male_10_to_14E', 'Male_15_to_17E',
              'Female_under_5E', 'Female_5_to_9E', 'Female_10_to_14E', 'Female_15_to_17E']


Data['Under18A'] = Data[Under18E].sum(1)

# %%
Under18M = ['Male_under_5M', 'Male_5_to_9M', 'Male_10_to_14M', 'Male_15_to_17M',
              'Female_under_5M', 'Female_5_to_9M', 'Female_10_to_14M', 'Female_15_to_17M']

Data['Under18NMO'] = Data[Under18M].sum(1)

Data['SexbyAgeDMO'] = Data['Sex_By_Age_TotalM']

# %% [markdown]
# ##### Over 65

# %%
Over65E = ['Male_65_to_66E', 'Male_67_to_69E', 'Male_70_to_74E', 'Male_75_to_79E', 'Male_80_to_84E',
             'Male_85_and_overE', 'Female_65_to_66E', 'Female_67_to_69E', 'Female_70_to_74E', 'Female_75_to_79E',
             'Female_80_to_84E', 'Female_85_and_overE']

Data['Over65A'] = Data[Over65E].sum(1)

# %%
Over65M = ['Male_65_to_66M', 'Male_67_to_69M', 'Male_70_to_74M', 'Male_75_to_79M', 'Male_80_to_84M',
             'Male_85_and_overM', 'Female_65_to_66M', 'Female_67_to_69M', 'Female_70_to_74M', 'Female_75_to_79M',
             'Female_80_to_84M', 'Female_85_and_overM']

Data['Over65NMO'] = Data[Over65M].sum(1)

# %% [markdown]
# ##### Race

# %%
RaceOtherE = ['AmericanIndianAloneE','NativeHawaiianAloneE','SomeOtherRaceAloneE','TwoorMoreRacesAloneE']

Data['RaceOtherA'] = Data[RaceOtherE].sum(1)

# %%
RaceOtherM = ['AmericanIndianAloneM','NativeHawaiianAloneM','SomeOtherRaceAloneM','TwoorMoreRacesAloneM']

Data['RaceOtherNMO'] = Data[RaceOtherM].sum(1)

Data['TotalRaceDMO'] = Data['TotalRaceM']

Data['AsianAloneNMO'] = Data['AsianAloneM']
Data['BlackAloneNMO'] = Data['BlackAloneM']
Data['WhiteAloneNMO'] = Data['WhiteAloneM']
Data['HispanicAloneNMO'] = Data['HispanicAloneM']

# %% [markdown]
# ##### Commute Alone

# %%
CommuteE = ['Drove_20_to_24E', 'Drove_25_to_29E', 'Drove_30_to_34E', 'Drove_35_to_44E', 
                 'Drove_45_to_59E', 'Drove_60_or_MoreE']

Data['DriveMoreThan20MinutesA'] = Data[CommuteE].sum(1)

# %%
CommuteM = ['Drove_20_to_24M', 'Drove_25_to_29M', 'Drove_30_to_34M', 'Drove_35_to_44M', 
                 'Drove_45_to_59M', 'Drove_60_or_MoreM']

Data['DriveMoreThan20MinutesNMO'] = Data[CommuteM].sum(1)

Data['TotalTransportationDMO'] = Data['TotalTransportationM']

# %% [markdown]
# ##### Percent Private (No School or Pre School)

# %%
PrivateE = ['Kindergaten_MaleE','Grade_1_to_4_MaleE','Grade_5_to_8_MaleE','Grade_9_to_12_MaleE',
          'Kindergaten_FemaleE','Grade_1_to_4_FemaleE','Grade_5_to_8_FemaleE','Grade_9_to_12_FemaleE']


PrivateTotalE = ['Kindergaten_TotalMaleE','Grade_1_to_4_TotalMaleE','Grade_5_to_8_TotalMaleE',
               'Grade_9_to_12_TotalMaleE','Kindergaten_TotalFemaleE','Grade_1_to_4_TotalFemaleE',
               'Grade_5_to_8_TotalFemaleE','Grade_9_to_12_TotalFemaleE' ]

Data['PrivateA'] = Data[PrivateE].sum(1)

Data['PrivateTotalA'] = Data[PrivateTotalE].sum(1)

# %%
PrivateM = ['Kindergaten_MaleM','Grade_1_to_4_MaleM','Grade_5_to_8_MaleM','Grade_9_to_12_MaleM',
          'Kindergaten_FemaleM','Grade_1_to_4_FemaleM','Grade_5_to_8_FemaleM','Grade_9_to_12_FemaleM']


PrivateTotalM = ['Kindergaten_TotalMaleM','Grade_1_to_4_TotalMaleM','Grade_5_to_8_TotalMaleM',
               'Grade_9_to_12_TotalMaleM','Kindergaten_TotalFemaleM','Grade_1_to_4_TotalFemaleM',
               'Grade_5_to_8_TotalFemaleM','Grade_9_to_12_TotalFemaleM' ]

Data['PrivateNMO'] = Data[PrivateM].sum(1)

Data['PrivateTotalDMO'] = Data[PrivateTotalM].sum(1)

# %% [markdown]
# ##### Adults With High School Diploma

# %%
HighschoolE = ['HighSchoolDiplomaE','GEDorAlternativeE','SomeCollegeLessThan1YearE',
              'SomeCollege1orMoreYearsNoDegreeE','AssociateDegreeE','BachelorsDegreeE',
             'MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE']  


Data['HighSchoolDiplomaA'] = Data[HighschoolE].sum(1)

# %%
HighschoolM = ['HighSchoolDiplomaM','GEDorAlternativeM','SomeCollegeLessThan1YearM',
              'SomeCollege1orMoreYearsNoDegreeM','AssociateDegreeM','BachelorsDegreeM',
             'MastersDegreeM','ProfessionalSchoolDegreeM','DoctorateDegreeM']  


Data['HighSchoolDiplomaNMO'] = Data[HighschoolM].sum(1)

Data['TotalEducationAttainmentDMO'] = Data['TotalEducationAttainmentM']

# %% [markdown]
# ##### Adults with At Least Bachelors Degrees

# %%
BachelorsE = ['BachelorsDegreeE','MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE']


Data['AdultsWithAtLeastBachelorsA'] = Data[BachelorsE].sum(1)

# %%
BachelorsM = ['BachelorsDegreeM','MastersDegreeM','ProfessionalSchoolDegreeM','DoctorateDegreeM']


Data['AdultsWithAtLeastBachelorsNMO'] = Data[BachelorsM].sum(1)

Data['TotalEducationAttainmentDMO'] = Data['TotalEducationAttainmentM']

# %% [markdown]
# ###### No Vehicle

# %%
NoVehicleE = ['RenterOccupiedNoVehicleE','OwnerOccupiedNoVehicleE']

Data['NoVehicleA'] = Data[NoVehicleE].sum(1)

# %%
NoVehicleM = ['RenterOccupiedNoVehicleM','OwnerOccupiedNoVehicleM']

Data['NoVehicleNMO'] = Data[NoVehicleM].sum(1)

Data['TotalVehicleByTenureDMO'] = Data['TotalVehicleByTenureM']

# %% [markdown]
# #### Drove Alone

# %%
Data['DroveAloneNMO'] = Data['DroveAloneM']
Data['TotalTransportationDMO'] = Data['TotalTransportationM']

# %% [markdown]
# #### Veteran

# %%
Data['VeteranNMO'] = Data['VeteranM']
Data['TotalVeteranDMO'] = Data['TotalVeteranM']

# %% [markdown]
# #### Unemployment

# %%
Data['EmployedNMO'] = Data['CivilianInLaborForceEmployedM']
Data['TotalInLaborForceDMO'] = Data['TotalInLaborForceM']

# %% [markdown]
# #### Internet Access

# %%
Data['BroadbandNMO'] = Data['BroadbandM']
Data['TotalBroadbandDMO'] = Data['TotalBroadbandM']

# %% [markdown]
# #### Vacancy

# %%
Data['VacantNMO'] = Data['VacantM']
Data['TotalOccupancyDMO'] = Data['TotalOccupancyM']

# %% [markdown]
# #### Occupied

# %%
Data['OccupiedNMO'] = Data['OccupiedM']
Data['TotalOccupancyDMO'] = Data['TotalOccupancyM']

# %% [markdown]
# #### OwnerOccupied

# %%
Data['OwnerOccupiedNMO'] = Data['OwnerOccupiedM']
Data['TotalOwnerOccupiedDMO'] = Data['TotalOwnerOccupiedM']

# %% [markdown]
# ### Derived Proportions
#
# - To create the derived proportion, we divide the aggregated estimates by the total estimates

# %% [markdown]
# #### Under 18

# %%
Data['PercentUnder18'] =  (Data['Under18A']/Data['Sex_By_Age_TotalE'])

# %% [markdown]
# #### Over65

# %%
 Data['PercentOver65'] = (Data['Over65A']/Data['Sex_By_Age_TotalE'])

# %% [markdown]
# #### Race

# %%
Data['PercentAsian'] = (Data['AsianAloneE']/Data['TotalRaceE'])
Data['PercentBlack'] = (Data['BlackAloneE']/Data['TotalRaceE'])
Data['PercentWhite'] = (Data['WhiteAloneE']/Data['TotalRaceE'])
Data['PercentHispanic'] = (Data['HispanicAloneE']/Data['TotalRaceE'])
Data['PercentOther'] = (Data['RaceOtherA']/Data['TotalRaceE'])

# %% [markdown]
# #### Commute

# %%
Data['PercentDroveMoreThan20Minutes'] = (Data['DriveMoreThan20MinutesA']/Data['TotalTransportationE'])

# %% [markdown]
# #### Highschool Diploma

# %%
Data['PercentHighSchoolDiploma'] = (Data['HighSchoolDiplomaA']/Data['TotalEducationAttainmentE'])

# %% [markdown]
# #### Bachelors

# %%
Data['PercentAdultsWithAtLeastBachelors'] = (Data['AdultsWithAtLeastBachelorsA']/Data['TotalEducationAttainmentE'])

# %% [markdown]
# #### Private (No School or Pre School)

# %%
Data['PercentPrivateSchool'] = Data['PrivateA']/Data['PrivateTotalA']    ## Not Percent but for consistency

# %% [markdown]
# #### Drove Alone

# %%
Data['PercentDroveAlone'] = Data['DroveAloneE']/Data['TotalTransportationE']

# %% [markdown]
# #### Veterans

# %%
Data['PercentVeteran'] = (Data['VeteranE']/Data['TotalVeteranE'])

# %% [markdown]
# #### Employment Status

# %%
 Data['PercentEmployed'] = (Data['CivilianInLaborForceEmployedE']/Data['TotalInLaborForceE'])

# %% [markdown]
# #### Internet Access

# %%
Data['PercentInternetAccess'] = Data['BroadbandE']/Data['TotalBroadbandE']

# %% [markdown]
# #### Vacant

# %%
Data['PercentVacant'] = (Data['VacantE']/Data['TotalOccupancyE'])

# %% [markdown]
# #### Occupied

# %%
Data['PercentOccupied'] = (Data['OccupiedE']/Data['TotalOccupancyE'])

# %% [markdown]
# #### Owner Occupied

# %%
Data['PercentOwnerOccupied'] = Data['OwnerOccupiedE']/Data['TotalOwnerOccupiedE']

# %% [markdown]
# #### No Vehicle

# %%
Data['PercentNoVehicle'] = (Data['NoVehicleA']/Data['TotalVehicleByTenureE'])

# %% [markdown]
# ### Square the percentages (Derived Proportion)
#
# - The next step to calculate the margin of error for our derived proportion is squaring our derived proportion

# %%
for row in Data: 
    if row.startswith('Per'):
        Data[str(row)+'PS'] = Data[str(row)]**2

# %% [markdown]
# ### Square MOE numerator and denominator
#
# - We then square the numerator of the margins of error

# %%
#For numerator

for row in Data:
    if row.endswith("NMO"):
        print(row)
# Out:
# Under18NMO
# Over65NMO
# RaceOtherNMO
# AsianAloneNMO
# BlackAloneNMO
# WhiteAloneNMO
# HispanicAloneNMO
# DriveMoreThan20MinutesNMO
# PrivateNMO
# HighSchoolDiplomaNMO
# AdultsWithAtLeastBachelorsNMO
# NoVehicleNMO
# DroveAloneNMO
# VeteranNMO
# EmployedNMO
# BroadbandNMO
# VacantNMO
# OccupiedNMO
# OwnerOccupiedNMO

# %%
#For denominator

for row in Data:
    if row.endswith("DMO"):
        print(row)
# Out:
# SexbyAgeDMO
# TotalRaceDMO
# TotalTransportationDMO
# PrivateTotalDMO
# TotalEducationAttainmentDMO
# TotalVehicleByTenureDMO
# TotalVeteranDMO
# TotalInLaborForceDMO
# TotalBroadbandDMO
# TotalOccupancyDMO
# TotalOwnerOccupiedDMO

# %% [markdown]
# #### Derived Proportion MOE
#
# - Following the formula below, we calculate the margin of error for derived proportions
#
# <img src="https://github.com/MLProject20/Data/blob/main/MOE.PNG?raw=true" width=300 height = 100/>
#
#
#  [Formula For Calculating MOE For Derived Proportion](https://github.com/MLProject20/Data/blob/main/MOE.PNG?raw=true 'Margin of Error for Derived Estimates')

# %% [markdown]
# #### Under 18 Derived Proportion MOE

# %%
Data['Under18DerivedMOEP'] = (np.sqrt(Data['Under18NMO'] -
                                      (Data['PercentUnder18PS']*Data['SexbyAgeDMO']))/Data['Sex_By_Age_TotalE'])
# Out:
# C:\Users\padu\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone-2\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
Data['Under18DerivedMOEPR'] = np.where(np.isnan(Data['Under18DerivedMOEP'])!= True,Data['Under18DerivedMOEP'],
                              (np.sqrt(Data['Under18NMO'] +
                                      (Data['PercentUnder18PS']*Data['SexbyAgeDMO']))/Data['Sex_By_Age_TotalE']))

# %%
np.where(np.isnan(Data['Under18DerivedMOEP']))
# Out:
# (array([ 25,  50,  68, 115, 118, 130, 149, 168, 195, 262, 279, 311, 330,
#         340], dtype=int64),)

# %%
np.where(np.isnan(Data['Under18DerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %% [markdown]
# #### Over65 Derived Proportion MOE

# %%
Data['Over65DerivedMOEP'] = (np.sqrt(Data['Over65NMO'] -
                                     (Data['PercentOver65PS']*Data['SexbyAgeDMO']))/Data['Sex_By_Age_TotalE'])

# %%
Data['Over65DerivedMOEPR'] = np.where(np.isnan(Data['Over65DerivedMOEP'])!= True,Data['Over65DerivedMOEP'],
                             (np.sqrt(Data['Over65NMO'] +
                                     (Data['PercentOver65PS']*Data['SexbyAgeDMO']))/Data['Sex_By_Age_TotalE']))

# %%
np.where(np.isnan(Data['Over65DerivedMOEP']))
# Out:
# (array([ 24,  38,  97, 114, 118, 173, 279, 312, 385, 439], dtype=int64),)

# %%
np.where(np.isnan(Data['Over65DerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %% [markdown]
# #### Race Derived Proportion MOE

# %%
Data['RaceOtherDerivedMOEP'] = (np.sqrt(Data['RaceOtherNMO']-
                                (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE'])



Data['RaceOtherDerivedMOEPR'] = np.where(np.isnan(Data['RaceOtherDerivedMOEP'])!= True,Data['RaceOtherDerivedMOEP'],
                              (np.sqrt(Data['RaceOtherNMO']+
                                (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE']))      

#**************************************************************


Data['AsianDerivedMOEP'] = (np.sqrt(Data['AsianAloneNMO']- 
                            (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE'])



Data['AsianDerivedMOEPR'] = np.where(np.isnan(Data['AsianDerivedMOEP'])!= True,Data['AsianDerivedMOEP'],
                             (np.sqrt(Data['AsianAloneNMO']+ 
                            (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE']))    

#**************************************************************
                                         
Data['BlackAloneDerivedMOEP'] = (np.sqrt(Data['BlackAloneNMO']- 
                                 (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE'])


Data['BlackAloneDerivedMOEPR'] = np.where(np.isnan(Data['BlackAloneDerivedMOEP'])!= True,Data['BlackAloneDerivedMOEP'],
                            (np.sqrt(Data['BlackAloneNMO']+ 
                                 (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE']))

#**************************************************************

Data['WhiteAloneDerivedMOEP'] = (np.sqrt(Data['WhiteAloneNMO']-
                                 (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE'])


Data['WhiteAloneDerivedMOEPR'] = np.where(np.isnan(Data['WhiteAloneDerivedMOEP'])!= True,Data['WhiteAloneDerivedMOEP'],
                            (np.sqrt(Data['WhiteAloneNMO']+
                                 (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE']))

#******************************************************************

Data['HispanicAloneDerivedMOEP'] = (np.sqrt(Data['HispanicAloneNMO']-
                                   (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE'])


Data['HispanicAloneDerivedMOEPR'] = np.where(np.isnan(Data['HispanicAloneDerivedMOEP'])!= True,Data['HispanicAloneDerivedMOEP'],
                            (np.sqrt(Data['HispanicAloneNMO']+
                                   (Data['PercentOtherPS']*Data['TotalRaceDMO']))/Data['TotalRaceE']))

# %%
np.where(np.isnan(Data['RaceOtherDerivedMOEP']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['RaceOtherDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['AsianDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['AsianDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['BlackAloneDerivedMOEP']))
# Out:
# (array([ 42,  81, 118, 144, 204, 279, 291, 328, 346, 413, 432], dtype=int64),)

# %%
np.where(np.isnan(Data['BlackAloneDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['WhiteAloneDerivedMOEP']))
# Out:
# (array([ 85, 118, 119, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['WhiteAloneDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['WhiteAloneDerivedMOEP']))
# Out:
# (array([ 85, 118, 119, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['HispanicAloneDerivedMOEP']))
# Out:
# (array([  6,  35,  59,  62,  85, 106, 118, 144, 162, 165, 167, 168, 186,
#         209, 236, 268, 279, 287, 291, 304, 325, 328, 349, 421, 437],
#        dtype=int64),)

# %%
np.where(np.isnan(Data['HispanicAloneDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %% [markdown]
# #### Drove More Than 20 Minutes Derived Proportion MOE

# %%
Data['DroveMoreThan20MinutesDerivedMOEP'] = (np.sqrt(Data['DriveMoreThan20MinutesNMO'] 
                                             - (Data['PercentDroveMoreThan20MinutesPS']* 
                                                Data['TotalTransportationDMO']))/Data['TotalTransportationE'])

# %%
Data['DroveMoreThan20MinutesDerivedMOEPR'] = np.where(np.isnan(Data['DroveMoreThan20MinutesDerivedMOEP'])!= True,
                                                      Data['DroveMoreThan20MinutesDerivedMOEP'],
                             (np.sqrt(Data['DriveMoreThan20MinutesNMO'] 
                                             + (Data['PercentDroveMoreThan20MinutesPS']* 
                                                Data['TotalTransportationDMO']))/Data['TotalTransportationE']))

# %%
np.where(np.isnan(Data['DroveMoreThan20MinutesDerivedMOEP']))
# Out:
# (array([  6,  12,  15,  38,  56,  86,  93, 104, 106, 109, 115, 118, 132,
#         135, 142, 148, 151, 200, 219, 240, 242, 261, 262, 279, 289, 292,
#         293, 295, 307, 317, 322, 330, 336, 339, 342, 345, 351, 385, 390,
#         408, 409, 411, 414, 415, 420, 438, 451], dtype=int64),)

# %%
np.where(np.isnan(Data['DroveMoreThan20MinutesDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %% [markdown]
# #### Percent Private (No School or Pre School) Derived Proportion MOE

# %%
Data['PrivateSchoolDerivedMOEP']= (np.sqrt(Data['PrivateNMO']-
                                   (Data['PercentPrivateSchoolPS']*Data['PrivateTotalDMO']))/Data['PrivateTotalA'])

# %%
Data['PrivateSchoolDerivedMOEPR'] = np.where(np.isnan(Data['PrivateSchoolDerivedMOEP'])!= True,
                                                      Data['PrivateSchoolDerivedMOEP'],
                            (np.sqrt(Data['PrivateNMO']+
                                   (Data['PercentPrivateSchoolPS']*Data['PrivateTotalDMO']))/Data['PrivateTotalA']))

# %%
np.where(np.isnan(Data['PrivateSchoolDerivedMOEP']))
# Out:
# (array([  6,  60,  64, 118, 279, 333, 415], dtype=int64),)

# %%
np.where(np.isnan(Data['PrivateSchoolDerivedMOEPR']))
# Out:
# (array([  6,  60,  64, 118, 279, 333], dtype=int64),)

# %% [markdown]
# ##### Adults With High School Diploma Derived Proportion MOE

# %%
Data['AdultsWithAtLeastBachelorsDerivedMOEP'] = (np.sqrt(Data['AdultsWithAtLeastBachelorsNMO']-
                                                 (Data['PercentAdultsWithAtLeastBachelorsPS']*
                                                          Data['TotalEducationAttainmentDMO']))
                                                 /Data['TotalEducationAttainmentE'])

# %%
Data['AdultsWithAtLeastBachelorsDerivedMOEPR'] = np.where(np.isnan(Data['AdultsWithAtLeastBachelorsDerivedMOEP'])!= True,
                                                     Data['AdultsWithAtLeastBachelorsDerivedMOEP'],
                           (np.sqrt(Data['AdultsWithAtLeastBachelorsNMO']+
                                                 (Data['PercentAdultsWithAtLeastBachelorsPS']*
                                                          Data['TotalEducationAttainmentDMO']))
                                                 /Data['TotalEducationAttainmentE']))

# %% [markdown]
# ##### Adults with At Least Bachelors Degrees Derived Proportion MOE

# %%
np.where(np.isnan(Data['AdultsWithAtLeastBachelorsDerivedMOEP']))
# Out:
# (array([ 16,  22,  23,  36,  39,  45,  93, 118, 125, 132, 147, 168, 183,
#         189, 200, 212, 219, 223, 235, 242, 279, 303, 309, 312, 318, 330,
#         334, 340, 345, 352, 366, 382, 384, 405, 407, 408, 409, 444, 449,
#         450, 456], dtype=int64),)

# %%
np.where(np.isnan(Data['AdultsWithAtLeastBachelorsDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %%
Data['HighSchoolDiplomaDerivedMOEP'] = (np.sqrt(Data['HighSchoolDiplomaNMO']-
                                                 (Data['PercentHighSchoolDiplomaPS']*
                                                          Data['TotalEducationAttainmentDMO']))
                                                 /Data['TotalEducationAttainmentE'])

# %%
Data['HighSchoolDiplomaDerivedMOEPR'] = np.where(np.isnan(Data['HighSchoolDiplomaDerivedMOEP'])!= True,
                                                      Data['HighSchoolDiplomaDerivedMOEP'],
                            (np.sqrt(Data['HighSchoolDiplomaNMO']+
                                                 (Data['PercentHighSchoolDiplomaPS']*
                                                          Data['TotalEducationAttainmentDMO']))
                                                 /Data['TotalEducationAttainmentE']))

# %%
np.where(np.isnan(Data['HighSchoolDiplomaDerivedMOEP']))
# Out:
# (array([  3,   7,   8,  12,  13,  15,  16,  17,  22,  23,  25,  27,  28,
#          32,  35,  36,  38,  39,  40,  45,  46,  47,  52,  56,  57,  58,
#          61,  62,  64,  68,  70,  78,  79,  81,  85,  86,  88,  89,  92,
#          94,  97,  99, 101, 104, 105, 106, 108, 109, 111, 114, 115, 118,
#         122, 125, 130, 131, 132, 133, 135, 138, 140, 144, 145, 147, 149,
#         152, 155, 158, 162, 166, 167, 168, 169, 171, 173, 176, 178, 183,
#         187, 188, 191, 195, 198, 200, 202, 203, 206, 212, 214, 223, 225,
#         227, 229, 231, 232, 235, 236, 246, 247, 252, 256, 261, 262, 264,
#         266, 268, 276, 277, 279, 282, 288, 289, 291, 292, 293, 294, 295,
#         299, 300, 303, 307, 309, 312, 316, 318, 322, 323, 325, 330, 335,
#         336, 340, 345, 351, 352, 356, 357, 359, 363, 364, 366, 368, 373,
#         382, 383, 384, 387, 395, 402, 405, 407, 408, 409, 410, 413, 414,
#         421, 423, 426, 432, 437, 441, 444, 449, 450, 451, 452, 453, 454,
#         456], dtype=int64),)

# %%
np.where(np.isnan(Data['HighSchoolDiplomaDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %% [markdown]
# #### Veteran Derived Proportion MOE

# %%
Data['VeteranDerivedMOEP'] = (np.sqrt(Data['NoVehicleNMO']-
                                                 (Data['PercentNoVehiclePS']*
                                                          Data['TotalVeteranDMO']))
                                                 /Data['TotalVeteranE'])

# %%
Data['VeteranDerivedMOEPR'] = np.where(np.isnan(Data['VeteranDerivedMOEP'])!= True,
                                                    Data['VeteranDerivedMOEP'],
                           (np.sqrt(Data['NoVehicleNMO']+
                                                 (Data['PercentNoVehiclePS']*
                                                          Data['TotalVeteranDMO']))
                                                 /Data['TotalVeteranE']))

# %%
np.where(np.isnan(Data['VeteranDerivedMOEP']))
# Out:
# (array([  6,  50,  60,  85,  93, 115, 118, 176, 195, 243, 262, 279, 288,
#         289, 306, 373], dtype=int64),)

# %%
np.where(np.isnan(Data['VeteranDerivedMOEPR']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %% [markdown]
# ####  Employment Derived Proportion MOE

# %%
Data['EmployedDerivedMOEP'] = (np.sqrt(Data['EmployedNMO']-
                                                 (Data['PercentEmployedPS']*
                                                          Data['TotalInLaborForceDMO']))
                                                 /Data['TotalInLaborForceE'])

# %%
Data['EmployedDerivedMOEPR'] = np.where(np.isnan(Data['EmployedDerivedMOEP'])!= True,
                                                    Data['EmployedDerivedMOEP'],
                          (np.sqrt(Data['EmployedNMO']+
                                                 (Data['PercentEmployedPS']*
                                                          Data['TotalInLaborForceDMO']))
                                                 /Data['TotalInLaborForceE']))

# %%
np.where(np.isnan(Data['EmployedDerivedMOEP']))
# Out:
# (array([  3,   5,   7,   8,   9,  14,  15,  17,  18,  23,  24,  27,  32,
#          40,  45,  47,  48,  54,  65,  67,  68,  70,  75,  76,  78,  83,
#          88,  90,  91,  95, 105, 106, 108, 109, 110, 111, 112, 115, 116,
#         117, 118, 124, 126, 129, 130, 134, 136, 139, 141, 147, 148, 158,
#         159, 166, 171, 176, 186, 188, 194, 198, 202, 205, 207, 209, 210,
#         215, 217, 218, 220, 224, 230, 233, 235, 238, 241, 246, 248, 252,
#         254, 255, 256, 258, 262, 264, 265, 266, 267, 269, 270, 273, 275,
#         278, 279, 283, 285, 290, 292, 297, 303, 306, 312, 316, 319, 320,
#         331, 334, 335, 338, 341, 347, 348, 350, 351, 360, 362, 375, 377,
#         380, 384, 388, 397, 398, 401, 403, 406, 412, 416, 417, 423, 432,
#         441, 444, 447, 451], dtype=int64),)

# %%
np.where(np.isnan(Data['EmployedDerivedMOEPR']))
# Out:
# (array([118, 279], dtype=int64),)

# %% [markdown]
# #### Internet Derived Proportion MOE

# %%
Data['BroadbandMOEP'] = (np.sqrt(Data['BroadbandNMO']-
                                                 (Data['PercentInternetAccessPS']*
                                                          Data['TotalBroadbandDMO']))
                                                 /Data['TotalBroadbandE'])

# %%
Data['BroadbandMOEPR'] = np.where(np.isnan(Data['BroadbandMOEP'])!= True,
                                                    Data['BroadbandMOEP'],
                          (np.sqrt(Data['BroadbandNMO']+
                                                 (Data['PercentInternetAccessPS']*
                                                          Data['TotalBroadbandDMO']))
                                                 /Data['TotalBroadbandE']))

# %%
np.where(np.isnan(Data['BroadbandMOEP']))
# Out:
# (array([ 24,  32,  48,  60,  61,  79,  89, 111, 118, 151, 177, 200, 217,
#         223, 226, 231, 253, 267, 269, 279, 295, 309, 317, 327, 349, 352,
#         380, 442, 444], dtype=int64),)

# %%
np.where(np.isnan(Data['BroadbandMOEPR']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %% [markdown]
# #### Vacancy Derived Proportion MOE

# %%
Data['VacantDerivedMOEP'] = (np.sqrt(Data['VacantNMO']-
                                                 (Data['PercentVacantPS']*
                                                          Data['TotalOccupancyDMO']))
                                                 /Data['TotalOccupancyE'])

# %%
Data['VacantDerivedMOEPR'] = np.where(np.isnan(Data['VacantDerivedMOEP'])!= True,
                                                   Data['VacantDerivedMOEP'],
                          (np.sqrt(Data['VacantNMO']+
                                                 (Data['PercentVacantPS']*
                                                          Data['TotalOccupancyDMO']))
                                                 /Data['TotalOccupancyE']))

# %%
np.where(np.isnan(Data['VacantDerivedMOEP']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['VacantDerivedMOEPR']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %% [markdown]
# #### Owner Occupied Derived Proportion MOE

# %%
Data['OccupiedMOEP'] = (np.sqrt(Data['OccupiedNMO']-
                                                 (Data['PercentOccupiedPS']*
                                                          Data['TotalOccupancyDMO']))
                                                 /Data['TotalOccupancyE'])

# %%
Data['OccupiedMOEPR'] = np.where(np.isnan(Data['OccupiedMOEP'])!= True,
                                                   Data['OccupiedMOEP'],
                          (np.sqrt(Data['OccupiedNMO']+
                                                 (Data['PercentOccupiedPS']*
                                                          Data['TotalOccupancyDMO']))
                                                 /Data['TotalOccupancyE']))

# %%
np.where(np.isnan(Data['OccupiedMOEP']))
# Out:
# (array([  2,  30,  54,  60,  66,  72, 118, 141, 148, 149, 170, 175, 186,
#         193, 220, 222, 258, 262, 263, 264, 279, 292, 323, 343, 347, 374,
#         393, 409, 412, 419, 421, 422, 430, 436, 437], dtype=int64),)

# %%
np.where(np.isnan(Data['OccupiedMOEPR']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %% [markdown]
# #### No Vehicle Derived Proportion MOE

# %%
Data['NoVehicleDerivedMOEP'] = (np.sqrt(Data['NoVehicleNMO']-
                                                 (Data['PercentNoVehiclePS']*
                                                          Data['TotalVehicleByTenureDMO']))
                                                 /Data['TotalVehicleByTenureE'])

# %%
Data['NoVehicleDerivedMOEPR'] = np.where(np.isnan(Data['NoVehicleDerivedMOEP'])!= True,
                                                   Data['NoVehicleDerivedMOEP'],
                         (np.sqrt(Data['NoVehicleNMO']+
                                                 (Data['PercentNoVehiclePS']*
                                                          Data['TotalVehicleByTenureDMO']))
                                                 /Data['TotalVehicleByTenureE']))

# %%
np.where(np.isnan(Data['NoVehicleDerivedMOEP']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %%
np.where(np.isnan(Data['NoVehicleDerivedMOEPR']))
# Out:
# (array([ 60, 118, 279], dtype=int64),)

# %% [markdown]
# ### Take square root of MOE to get their raw values

# %%
for row in Data:
    if row not in ('NAME'):
        if row.endswith("M"):
            Data[str(row)] = np.sqrt(Data[str(row)])

# %% [markdown]
# ### Multiply derived proportion by 100 to get percentages

# %%
for row in Data: 
    if row.startswith('Per'):
        Data[str(row)] = Data[str(row)]*100

# %%
for row in Data: 
    if row.endswith('MOEPR'):
        Data[str(row)] = Data[str(row)]*100

# %% [markdown]
# #### Data Cleaning
#
# - Get a list of columns added during MOE computation, add GEOID columns and delete them

# %%
delete = ['Under18MOEZero', 'Under18MOENonZero', 'Over65MOEZero', 
          'Over65MOENonZero', 'OtherMOEZero', 'OtherMOENonZero', 
          'DroveMOEZero', 'DroveMOENonZero', 'PrivateNoSchoolMOEZero', 
          'PrivateNoSchoolMOENonZero', 'PrivateNoSchoolTotalMOEDZero', 'PrivateNoSchoolTotalMOEDNonZero', 
          'HighSchoolDiplomaMOEZero', 'HighSchoolDiplomaMOENonZero', 'AdultsWithAtLeastBachelorsMOEZero',
          'AdultsWithAtLeastBachelorsMOENonZero', 'NoVehicleMOEZero', 'NoVehicleMOENonZero',
          'GEOID2', 'TotalRaceMOED', 'TotalTransportationMOED', 
          'PrivateNoSchoolTotalMOED', 'TotalEducationAttainmentMOED', 
          'TotalVeteranMOED', 'TotalInLaborForceMOED', 'TotalOccupancyMOED', 
          'TotalVehicleByTenureMOED','Under18NMO', 'Over65NMO', 'RaceOtherNMO', 'AsianAloneNMO', 'BlackAloneNMO', 
          'WhiteAloneNMO', 'HispanicAloneNMO', 'DriveMoreThan20MinutesNMO', 
          'PrivateNMO', 'HighSchoolDiplomaNMO',
          'AdultsWithAtLeastBachelorsNMO', 'NoVehicleNMO', 'VeteranNMO','DroveAloneNMO', 
          'EmployedNMO', 'VacantNMO', 'OccupiedNMO','SexbyAgeDMO', 'TotalRaceDMO', 
          'TotalTransportationDMO', 'PercentUnder18PS', 'PercentOver65PS', 'PercentAsianPS',
          'PercentBlackPS', 'PercentWhitePS', 'PercentHispanicPS', 'PercentOtherPS', 'PercentDroveMoreThan20MinutesPS',
          'PercentHighSchoolDiplomaPS', 'PercentAdultsWithAtLeastBachelorsPS', 'PercentPrivateSchoolPS','PercentOwnerOccupiedPS',
          'PercentVeteranPS', 'PercentEmployedPS', 'PercentVacantPS', 'PercentOccupiedPS', 'PercentNoVehiclePS',
          'PrivateTotalDMO', 'TotalEducationAttainmentDMO', 
          'TotalVehicleByTenureDMO', 'TotalVeteranDMO', 'TotalInLaborForceDMO', 'TotalOccupancyDMO']

Data.drop(delete,axis =1, inplace= True)

# %% [markdown]
# ### Rename Columns

# %% [markdown]
# ### Internet

# %%
year = '_2020'
margin = '_accuracy'

# %%
Data['r88'+year] = Data['BroadbandE']
Data['m88'+year+margin] = Data['BroadbandMOEPR']
Data['d88'+year] = Data['TotalBroadbandE']
Data['m88'+year] = Data['PercentInternetAccess']

# %% [markdown]
# #### Sex By Age

# %% [markdown]
# #### Population Youth

# %%
Under18E = ['Male_under_5E', 'Male_5_to_9E', 'Male_10_to_14E', 'Male_15_to_17E',
              'Female_under_5E', 'Female_5_to_9E', 'Female_10_to_14E', 'Female_15_to_17E']


Data['r12'+year] = Data[Under18E].sum(1)

Data['d12'+year] = Data['Sex_By_Age_TotalE']

Data['m12'+year] = Data['PercentUnder18']

Data['m12'+year+margin] = Data['Under18DerivedMOEPR']

# %% [markdown]
# #### Population Adult

# %%
Over65E = ['Male_65_to_66E', 'Male_67_to_69E', 'Male_70_to_74E', 'Male_75_to_79E', 'Male_80_to_84E',
             'Male_85_and_overE', 'Female_65_to_66E', 'Female_67_to_69E', 'Female_70_to_74E', 'Female_75_to_79E',
             'Female_80_to_84E', 'Female_85_and_overE']

Data['r13'+year] = Data[Over65E].sum(1)

Data['d13'+year] = Data['Sex_By_Age_TotalE']

Data['m13'+year] = Data['PercentOver65']

Data['m13'+year+margin] = Data['Over65DerivedMOEPR']

# %% [markdown]
# #### Education Attainment

# %% [markdown]
# #### High School Diploma

# %%
HighschoolE = ['HighSchoolDiplomaE','GEDorAlternativeE','SomeCollegeLessThan1YearE',
              'SomeCollege1orMoreYearsNoDegreeE','AssociateDegreeE','BachelorsDegreeE',
             'MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE']  


Data['r39'+year] = Data[HighschoolE].sum(1)

Data['d39'+year] = Data['TotalEducationAttainmentE']

Data['m39'+year] = Data['PercentHighSchoolDiploma']

Data['m39'+year+margin] = Data['HighSchoolDiplomaDerivedMOEPR']

# %% [markdown]
# #### Bachelor's Degree

# %%
BachelorsE = ['BachelorsDegreeE','MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE']


Data['r20'+year] = Data[BachelorsE].sum(1)

Data['d20'+year] = Data['TotalEducationAttainmentE']

Data['m20'+year] = Data['PercentAdultsWithAtLeastBachelors']

Data['m20'+year+margin] = Data['AdultsWithAtLeastBachelorsDerivedMOEPR']

# %% [markdown]
# ###### No Vehicle

# %%
# NoVehicleE = ['RenterOccupiedNoVehicleE','OwnerOccupiedNoVehicleE']

# Data['NoVehicleA'] = Data[NoVehicleE].sum(1)

# %%
# NoVehicleM = ['RenterOccupiedNoVehicleM','OwnerOccupiedNoVehicleM']

# Data['NoVehicleNMO'] = Data[NoVehicleM].sum(1)

# Data['TotalVehicleByTenureDMO'] = Data['TotalVehicleByTenureM']

# %% [markdown]
# #### Drove Alone

# %%
Data['r10'+year] = Data['DroveAloneE']
Data['m10'+year+margin] = Data['DroveMoreThan20MinutesDerivedMOEPR']

Data['m10'+year] = Data['PercentDroveAlone']

Data['d10'+year] = Data['TotalTransportationE']

# %% [markdown]
# #### Veteran

# %%
# Data['VeteranNMO'] = Data['VeteranM']
# Data['TotalVeteranDMO'] = Data['TotalVeteranM']

# %% [markdown]
# #### Unemployment

# %%
Data['r38'+year] = Data['CivilianInLaborForceEmployedE']
Data['m38'+year+margin] = Data['EmployedDerivedMOEPR']

Data['d38'+year] = Data['TotalInLaborForceE']

Data['m38'+year] = Data['PercentEmployed']

# %% [markdown]
# ##### Race

# %%
RaceOtherE = ['AmericanIndianAloneE','NativeHawaiianAloneE','SomeOtherRaceAloneE','TwoorMoreRacesAloneE']
RaceOtherM = ['AmericanIndianAloneM','NativeHawaiianAloneM','SomeOtherRaceAloneM','TwoorMoreRacesAloneM']

Data['r16'+year] = Data['AsianAloneE']
Data['r15'+year] = Data['BlackAloneE']
Data['r14'+year] = Data['WhiteAloneE']
Data['r18'+year] = Data['HispanicAloneE']
Data['r17'+year] = Data[RaceOtherE].sum(1)

Data['m16'+year] = Data['PercentAsian']
Data['m15'+year] = Data['PercentBlack']
Data['m14'+year] = Data['PercentWhite']
Data['m18'+year] = Data['PercentHispanic']
Data['m17'+year] = Data['PercentOther']

Data['d16'+year] = Data['TotalRaceE']
Data['d15'+year] = Data['TotalRaceE']
Data['d14'+year] = Data['TotalRaceE']
Data['d18'+year] = Data['TotalRaceE']
Data['d17'+year] = Data['TotalRaceE']

# %%
Data['m16'+year+margin] = Data['AsianDerivedMOEPR']
Data['m15'+year+margin] = Data['BlackAloneDerivedMOEPR']
Data['m14'+year+margin] = Data['WhiteAloneDerivedMOEPR']
Data['m18'+year+margin] = Data['HispanicAloneDerivedMOEPR']
Data['m17'+year+margin] = Data['RaceOtherDerivedMOEPR']

# %% [markdown]
# #### Owner Occupied

# %%
Data['r29'+year] = Data['OwnerOccupiedE']
Data['m29'+year+margin] = Data['OccupiedMOEPR']
Data['m29'+year] = Data['PercentOwnerOccupied']

Data['d29'+year] = Data['TotalOwnerOccupiedE']

# %% [markdown]
# #### Long Commute

# %%
CommuteE = ['Drove_20_to_24E', 'Drove_25_to_29E', 'Drove_30_to_34E', 'Drove_35_to_44E', 
                 'Drove_45_to_59E', 'Drove_60_or_MoreE']

Data['r33'+year] = Data[CommuteE].sum(1)

# %%
Data['m33'+year+margin] = Data['DroveMoreThan20MinutesDerivedMOEPR']

Data['m33'+year] = Data['PercentDroveMoreThan20Minutes']

Data['d33'+year] = Data['TotalTransportationE']

# %% [markdown]
# #### Residential Occupancy

# %%
Data['r31'+year] = Data['VacantE']
Data['m31'+year+margin] = Data['VacantDerivedMOEPR']
Data['m31'+year] = Data['PercentVacant'] 

Data['d31'+year] = Data['TotalOccupancyE']

# %% [markdown]
# ### Exports

# %%
UICode = ['r10_2020', 'd10_2020', 'm10_2020', 'm10_2020_accuracy', 'r12_2020','d12_2020','m12_2020','m12_2020_accuracy', 
          'r13_2020', 'd13_2020', 'm13_2020', 'm13_2020_accuracy','r14_2020', 'd14_2020', 'm14_2020', 'm14_2020_accuracy',
          'r15_2020', 'd15_2020', 'm15_2020', 'm15_2020_accuracy','r16_2020', 'd16_2020', 'm16_2020', 'm16_2020_accuracy',
          'r17_2020', 'd17_2020', 'm17_2020', 'm17_2020_accuracy','r18_2020', 'd18_2020', 'm18_2020', 'm18_2020_accuracy',
          'r20_2020', 'd20_2020','m20_2020', 'm20_2020_accuracy','r29_2020', 'd29_2020', 'm29_2020', 'm29_2020_accuracy',
          'r31_2020', 'd31_2020', 'm31_2020', 'm31_2020_accuracy','r33_2020', 'd33_2020', 'm33_2020', 'm33_2020_accuracy',
          'r38_2020', 'd38_2020', 'm38_2020', 'm38_2020_accuracy','r39_2020', 'd39_2020', 'm39_2020', 'm39_2020_accuracy',
          'r88_2020','d88_2020','m88_2020','m88_2020_accuracy']

# %%
for row in range(0,len(UICode)-1,4):
    QOLID = pd.DataFrame(Data[UICode[row:row+4]])
    QOLID.to_csv(str(UICode[row][:3])+".csv")

# %%
DataUI = pd.DataFrame(Data[UICode])

DataUI.to_csv('QualityofLife2020.csv')

# %%
# ## Under18 

# Under18 = ['Male_under_5E', 'Male_under_5M', 'Male_5_to_9E', 'Male_5_to_9M',
#            'Male_10_to_14E', 'Male_10_to_14M', 'Male_15_to_17E', 'Male_15_to_17M', 'Under18MOEN', 
#            'Under18A', 'Under18DerivedMOEP', 'Under18DerivedMOEPR','PercentUnder18','SexbyAgeMOED','Sex_By_Age_TotalE']

# U18 = pd.DataFrame(Data[Under18])
# U18.to_csv('Under18.csv')

# ### Over65

# over65 = ['Male_15_to_17E', 'Male_15_to_17M', 'Male_65_to_66E', 'Male_65_to_66M', 'Male_67_to_69E',
#           'Male_67_to_69M', 'Male_70_to_74E', 'Male_70_to_74M', 'Male_75_to_79E', 'Male_75_to_79M',
#           'Male_80_to_84E', 'Male_80_to_84M', 'Male_85_and_overE','PercentOver65','Sex_By_Age_TotalM',
#           'Male_85_and_overM', 'Over65MOEN', 'Over65A', 'Over65DerivedMOEP', 'Over65DerivedMOEPR']
# O68 = pd.DataFrame(Data[over65])
# O68.to_csv('Over65.csv')

# %%
# ### Race 

# Race = ['AmericanIndianAloneM','NativeHawaiianAloneM','AsianAloneM','AsianAloneE','PercentAsian',
#         'SomeOtherRaceAloneM','TwoorMoreRacesAloneM','AmericanIndianAloneE','BlackAloneM','BlackAloneE',
#         'PercentBlack','WhiteAloneM','WhiteAloneE','PercentWhite','HispanicAloneM','HispanicAloneE','PercentHispanic',
#         'NativeHawaiianAloneE','SomeOtherRaceAloneE','PercentOther','TwoorMoreRacesAloneE','TotalRaceM','AsianDerivedMOEPR',
#         'BlackAloneDerivedMOEPR','WhiteAloneDerivedMOEPR','HispanicAloneDerivedMOEPR','RaceOtherDerivedMOEPR'
#        ]

# Race = pd.DataFrame(Data[Race])
# Race.to_csv("Race.csv")

# %%
# ## Drove

# Drove = ['DroveAloneE', 'DroveAloneM', 'Drove_20_to_24E', 'Drove_20_to_24M', 'Drove_25_to_29E',
#  'Drove_25_to_29M', 'Drove_30_to_34E', 
#  'Drove_30_to_34M', 'Drove_35_to_44E', 'Drove_35_to_44M', 'Drove_45_to_59E', 
#  'Drove_45_to_59M', 'Drove_60_or_MoreE', 'PercentDroveMoreThan20Minutes',
#  'Drove_60_or_MoreM', 'DroveMoreThan20MinutesMOEN', 
#  'DroveMoreThan20MinutesDerivedMOEP', 'DroveMoreThan20MinutesDerivedMOEPR',
#          'TotalTransportationE','TotalTransportationM']

# Drove20 = pd.DataFrame(Data[Drove])
# Drove20.to_csv("Drove20.csv")

# %%
# ## Private School
# Private = ['Kindergaten_TotalMaleE','Grade_1_to_4_TotalMaleE','Grade_5_to_8_TotalMaleE',
#                'Grade_9_to_12_TotalMaleE','Kindergaten_TotalFemaleE','Grade_1_to_4_TotalFemaleE',
#                'Grade_5_to_8_TotalFemaleE','Grade_9_to_12_TotalFemaleE' ,
#           'Kindergaten_MaleE','Grade_1_to_4_MaleE','Grade_5_to_8_MaleE','Grade_9_to_12_MaleE',
#           'Kindergaten_FemaleE','Grade_1_to_4_FemaleE','Grade_5_to_8_FemaleE','Grade_9_to_12_FemaleE',
#            'Kindergaten_MaleM','Grade_1_to_4_MaleM','Grade_5_to_8_MaleM','Grade_9_to_12_MaleM',
#           'Kindergaten_FemaleM','Grade_1_to_4_FemaleM','Grade_5_to_8_FemaleM','Grade_9_to_12_FemaleM',
#           'Kindergaten_TotalMaleM','Grade_1_to_4_TotalMaleM','Grade_5_to_8_TotalMaleM',
#                'Grade_9_to_12_TotalMaleM','Kindergaten_TotalFemaleM','Grade_1_to_4_TotalFemaleM',
#                'Grade_5_to_8_TotalFemaleM','Grade_9_to_12_TotalFemaleM','PercentPrivateSchool' 
#           ]

# Private = pd.DataFrame(Data[Private])
# Private.to_csv("Privateschool.csv")

# %%
# ## HighSchool 

# High = ['HighSchoolDiplomaE','GEDorAlternativeE','SomeCollegeLessThan1YearE',
#               'SomeCollege1orMoreYearsNoDegreeE','AssociateDegreeE','BachelorsDegreeE',
#              'MastersDegreeE','ProfessionalSchoolDegreeE','DoctorateDegreeE',
#         'HighSchoolDiplomaM','GEDorAlternativeM','SomeCollegeLessThan1YearM',
#               'SomeCollege1orMoreYearsNoDegreeM','AssociateDegreeM','BachelorsDegreeM',
#              'MastersDegreeM','ProfessionalSchoolDegreeM','DoctorateDegreeM','TotalEducationAttainmentM',
#         'TotalEducationAttainmentE','PercentHighSchoolDiploma','HighSchoolDiplomaDerivedMOEPR'
#        ]  

# High = pd.DataFrame(Data[High])
# High.to_csv("HighSchool.csv")

# %%
# ## Bachelors 

# Bachelors =  ['BachelorsDegreeE','MastersDegreeE','ProfessionalSchoolDegreeE',
#               'DoctorateDegreeE','BachelorsDegreeM','MastersDegreeM','ProfessionalSchoolDegreeM',
#               'DoctorateDegreeM','TotalEducationAttainmentM', 'TotalEducationAttainmentE','PercentAdultsWithAtLeastBachelors',
#              'AdultsWithAtLeastBachelorsDerivedMOEP','AdultsWithAtLeastBachelorsDerivedMOEPR']

# Bachelor = pd.DataFrame(Data[Bachelors])
# Bachelor.to_csv("Bachelors.csv")

# %%
# ## Veteran

# Veteran = ['VeteranM','TotalVeteranM','VeteranE','PercentVeteran','VeteranDerivedMOEPR']

# Veteran = pd.DataFrame(Data[Veteran] )

# Veteran.to_csv("Veteran.csv")

# %%
Data.to_csv('QualityOfLifeExplorer.csv')
